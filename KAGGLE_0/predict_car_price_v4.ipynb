# %%
# для автозагрузки изменений в модулях без необходимости перезагрузки kelner
# %load_ext autoreload
# %autoreload 2


# необходимо для корректного импорта своих модулей в JupyterLab
import sys
current_dir = sys.path[0]
project_dir = 'SF_DS_Pro'
last_position = current_dir.find(project_dir) + len(project_dir)
project_path = current_dir[:last_position]
sys.path.append(project_path)


# %matplotlib inline
import matplotlib.pyplot as plt # библиотека визуализации
import seaborn as sns
# sns.set_style('whitegrid')
plt.style.use('ggplot')
sns.set(rc={'figure.figsize':(10, 8)})

import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)

import warnings
warnings.filterwarnings('ignore')


from IPython.core.display import HTML
HTML("""
<style>
.p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
  padding: 0;
  border: 0;
}
</style>
""")
# Out:
# <style>
# .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#   padding: 0;
#   border: 0;
# }
# </style>

# %% [markdown]
# ## 0. Prerequisites

# %% [markdown]
# ### 0.0. install LightAutoML

# %% [markdown]
# ### 0.1. Import libraries
#
# Here we will import the libraries we use in this kernel:
# - Standard python libraries for timing, working with OS etc.
# - Essential python DS libraries like numpy, pandas, scikit-learn and torch (the last we will use in the next cell)
# - LightAutoML modules: `TabularAutoML` preset for AutoML model creation and Task class to setup what kind of ML problem we solve (binary/multiclass classification or regression)

# %%
# Standard python libraries
import os
import time

# Essential DS libraries
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import torch

# LightAutoML presets, task and report generation
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task

import Handlers as hd

# %%
from comet_ml import Experiment
experiment = Experiment(
    api_key="I1vM5jywyHjyrHOHaffYqCv6z",
    project_name="predict-car-price",
    workspace="chepell",
)
# Out:
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: torch, lightgbm, sklearn. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/chepell/predict-car-price/24ebdb1131664694b99fb91a2d9c4c2c

# %%
submission_file_name = 'del_mil_stranges_and_outliers.csv'

text = submission_file_name + '\nПочти пустой вариант, где только удалил записи deal_type = For Rent.\n Удалил полностью нулевую запись, где год = 0.\n'
text = text + 'Преобразовал год в возраст.\n Полные дубликаты не удалял, сильно падает производительность.\n Удалил вылеты в возрасте по методу тьюки.\n'
text = text + 'final_price отчистил от очевидных вылетов 0 цена и выше 1млн, но дальше не стал вычищать выбросы.\n'
text = text + 'current_mileage отчистил от очевидных вылетов по метожу тьюки, все что выше 300т миль. И убрал странные записи когда пробег в виде одного повторяющегося числа\n'

experiment.log_text(text, step=None, metadata=None)
# Out:
# {'web': 'https://www.comet.ml/api/asset/download?assetId=abe4f4109c4444bbb2aa4dd99ed40e83&experimentKey=24ebdb1131664694b99fb91a2d9c4c2c',
#  'api': 'https://www.comet.ml/api/rest/v2/experiment/asset/get-asset?assetId=abe4f4109c4444bbb2aa4dd99ed40e83&experimentKey=24ebdb1131664694b99fb91a2d9c4c2c',
#  'assetId': 'abe4f4109c4444bbb2aa4dd99ed40e83'}

# %% [markdown]
# ### 0.2. Constants
#
# Here we setup the constants to use in the kernel:
# - `N_THREADS` - number of vCPUs for LightAutoML model creation
# - `N_FOLDS` - number of folds in LightAutoML inner CV
# - `RANDOM_STATE` - random seed for better reproducibility
# - `TEST_SIZE` - houldout data part size
# - `TIMEOUT` - limit in seconds for model to train
# - `TARGET_NAME` - target column name in dataset

# %%
N_THREADS = 4
N_FOLDS = 5
RANDOM_STATE = 42
TEST_SIZE = 0.2
TIMEOUT = 30 * 60 # mins
TARGET_NAME = 'final_price'

# %% [markdown]
# ### 0.3. Imported models setup
#
# For better reproducibility fix numpy random seed with max number of threads for Torch (which usually try to use all the threads on server):

# %%
np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

# %% [markdown]
# ### 0.4. Data loading
# Let's check the data we have:

# %%
INPUT_DIR = 'data/'

# %%
train_data = pd.read_csv(INPUT_DIR + 'train_data.csv.zip')
print(train_data.shape)
train_data.head()
# Out:
# (35000, 15)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA        Aqua s            Sedan
# 1       1        MERCEDES-BENZ         C 220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
# 3       3              HYUNDAI      Santa FE             Jeep
# 4       4               TOYOTA           CHR             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
# 3           115459          2015            Automatic       4/5
# 4            18950          2019            Automatic       4/5
#
#                   wheels vehicle_color vehicle_interior_color  \
# 0    Right-hand drive          Silver                  Black
# 1           Left wheel         Silver                  Black
# 2           Left wheel         Silver                  Black
# 3           Left wheel           Blue                  Black
# 4           Left wheel          Black                     NaN
#
#                car_vin  car_leather_interior deal_type  final_price
# 0                  NaN                     0  For Sale      3650.00
# 1                  NaN                     0  For Sale      6800.00
# 2   KMHTC6AE3GU293912                      1  For Sale      6300.00
# 3                  NaN                     1  For Sale     14488.00
# 4   JTNKHMBX7K1030253                      1  For Sale      5000.00

# %%
test_data = pd.read_csv(INPUT_DIR + 'test_data.csv.zip')
print(test_data.shape)
test_data.head()
# Out:
# (10697, 14)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0   35000               TOYOTA         Prius        Hatchback
# 1   35001              HYUNDAI       Elantra            Sedan
# 2   35002                LEXUS        NX 300             Jeep
# 3   35003                LEXUS       CT 200h        Hatchback
# 4   35004               TOYOTA         RAV 4             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           323733          2012            Automatic       4/5
# 1           112000          2013            Tiptronic       4/5
# 2            16920          2018            Automatic       NaN
# 3           302742          2012            Automatic       4/5
# 4             1800          2002               Manual       4/5
#
#            wheels vehicle_color vehicle_interior_color              car_vin  \
# 0    Left wheel           Grey                  Black    JTDKN3DU6C5439638
# 1    Left wheel           Grey                  Black            SURATSHIA
# 2    Left wheel          Brown                     NaN   JTJYARBZ5J2104521
# 3    Left wheel          White                     NaN   JTHKD5BH4C2070945
# 4    Left wheel         Silver                  Black                   NaN
#
#    car_leather_interior deal_type
# 0                     1  For Sale
# 1                     1  For Sale
# 2                     1  For Sale
# 3                     1  For Sale
# 4                     0  For Sale

# %%
submission = pd.read_csv(INPUT_DIR + 'sample_submission.csv')
print(submission.shape)
submission.head()
# Out:
# (10697, 2)
#    row_ID  final_price
# 0   35000            0
# 1   35001            0
# 2   35002            0
# 3   35003            0
# 4   35004            0

# %% [markdown]
# ### Step 0.5. Some user feature preparation
#
# Be creative :)

# %%
train_data
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0           0               TOYOTA        Aqua s            Sedan
# 1           1        MERCEDES-BENZ         C 220            Sedan
# 2           2              HYUNDAI      Veloster        Hatchback
# 3           3              HYUNDAI      Santa FE             Jeep
# 4           4               TOYOTA           CHR             Jeep
# ...       ...                  ...           ...              ...
# 34995   34995                 FORD        Fusion            Sedan
# 34996   34996            SSANGYONG        REXTON             Jeep
# 34997   34997                  BMW           635            Sedan
# 34998   34998              HYUNDAI        Tucson             Jeep
# 34999   34999               TOYOTA        Avalon            Sedan
#
#        current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0               133000          2014            Automatic       4/5
# 1                24500          2010               Manual       4/5
# 2                31000          2016            Tiptronic       2/3
# 3               115459          2015            Automatic       4/5
# 4                18950          2019            Automatic       4/5
# ...                ...           ...                  ...       ...
# 34995            87579          2013            Automatic       4/5
# 34996           116092          2009            Automatic       4/5
# 34997            43000          2015            Tiptronic       4/5
# 34998            82139          2015            Automatic       4/5
# 34999           237178          2015            Automatic       4/5
#
#                       wheels vehicle_color vehicle_interior_color  \
# 0        Right-hand drive          Silver                  Black
# 1               Left wheel         Silver                  Black
# 2               Left wheel         Silver                  Black
# 3               Left wheel           Blue                  Black
# 4               Left wheel          Black                     NaN
# ...                      ...           ...                    ...
# 34995           Left wheel          Black                     NaN
# 34996           Left wheel         Silver                  Black
# 34997           Left wheel           Grey                   Grey
# 34998           Left wheel          White                  Black
# 34999           Left wheel           Blue                  Black
#
#                    car_vin  car_leather_interior deal_type  final_price
# 0                      NaN                     0  For Sale      3650.00
# 1                      NaN                     0  For Sale      6800.00
# 2       KMHTC6AE3GU293912                      1  For Sale      6300.00
# 3                      NaN                     1  For Sale     14488.00
# 4       JTNKHMBX7K1030253                      1  For Sale      5000.00
# ...                    ...                   ...       ...          ...
# 34995   3FA6P0K98DR308742                      1  For Sale      6000.00
# 34996                  NaN                     1  For Sale      9642.00
# 34997                  NaN                     1  For Sale     23500.00
# 34998                  NaN                     1  For Sale     12826.00
# 34999                  NaN                     1  For Sale      1050.00
#
# [35000 rows x 15 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   row_ID                  35000 non-null  int64
#  1   vehicle_manufacturer    34999 non-null  object
#  2   vehicle_model           34993 non-null  object
#  3   vehicle_category        34999 non-null  object
#  4   current_mileage         35000 non-null  int64
#  5   vehicle_year            35000 non-null  int64
#  6   vehicle_gearbox_type    34999 non-null  object
#  7   doors_cnt               34255 non-null  object
#  8   wheels                  34999 non-null  object
#  9   vehicle_color           34599 non-null  object
#  10  vehicle_interior_color  28282 non-null  object
#  11  car_vin                 11488 non-null  object
#  12  car_leather_interior    35000 non-null  int64
#  13  deal_type               35000 non-null  object
#  14  final_price             35000 non-null  float64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 4.0+ MB

# %%
# Смотрю информацию по пропускам в столбцах
hd.get_columns_null_info_df(train_data)
# Out:
#                Column Name  Count Null  % Null     Type
# 0                   row_ID           0    0.00    int64
# 1     vehicle_manufacturer           1    0.00   object
# 2            vehicle_model           7    0.02   object
# 3         vehicle_category           1    0.00   object
# 4          current_mileage           0    0.00    int64
# 5             vehicle_year           0    0.00    int64
# 6     vehicle_gearbox_type           1    0.00   object
# 7                doors_cnt         745    2.13   object
# 8                   wheels           1    0.00   object
# 9            vehicle_color         401    1.15   object
# 10  vehicle_interior_color        6718   19.19   object
# 11                 car_vin       23512   67.18   object
# 12    car_leather_interior           0    0.00    int64
# 13               deal_type           0    0.00   object
# 14             final_price           0    0.00  float64

# %%
# Больше всего пропусков в car_vin все же надо как-то его обрабатывать
# Там где заменяю нулами все пропуски и все некорректные вин, которые меньше 17.

# Надо что-то с цветом интерьера делать - вариант добавить UNKNOWN цвет для нулевых значений

# %%
# Информация по уникальным значениям
hd.get_top_unique_values(train_data)
# Out:
#                Column Name  Count Unique            Top Value  Top Value %  \
# 0     vehicle_manufacturer            68               TOYOTA        19.34
# 1            vehicle_model          2224                Prius         6.72
# 2         vehicle_category            11                Sedan        44.24
# 3          current_mileage         11273                    0         4.01
# 4             vehicle_year            68                 2012        11.20
# 5     vehicle_gearbox_type             4            Automatic        69.40
# 6                doors_cnt             3                  4/5        94.72
# 7                   wheels             2         Left wheel          92.02
# 8            vehicle_color            16               Black         26.17
# 9   vehicle_interior_color            11               Black         74.55
# 10                 car_vin          4288   3VW1K7AJ6EM438747          0.37
# 11    car_leather_interior             2                    1        71.55
# 12               deal_type             2             For Sale        98.21
# 13             final_price          2939               150.00         1.59
#
#     Top Value Count
# 0              6768
# 1              2350
# 2             15483
# 3              1403
# 4              3919
# 5             24290
# 6             32446
# 7             32207
# 8              9053
# 9             21083
# 10               42
# 11            25042
# 12            34372
# 13              555

# %%
# в daal_type 98% приходится на продажи, остальное рента, признак неинфомативен

# %% [markdown]
# deal_type и doors_cnt самые неуникальные признаки.\
# deal_type имеет два варианта, на продажу и аренда, нас же в принципе интересует предсказание цены продажи.\
# Из тренировочной выборки удаляю авто которые под аренду.\
# А сам столбец добавляю в исключения модели в роли для тестового датафрейма.\
#
# doors_cnt просто добавляю в роли в качестве исключения.

# %%
# Оставляю только записи deal_type со значением For Sale. Сам признак в тестовой выборке помещаю в исключения через role
train_data = train_data[train_data['deal_type'] == 'For Sale']

# %%
print(train_data.shape)
train_data
# Out:
# (34372, 15)
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0           0               TOYOTA        Aqua s            Sedan
# 1           1        MERCEDES-BENZ         C 220            Sedan
# 2           2              HYUNDAI      Veloster        Hatchback
# 3           3              HYUNDAI      Santa FE             Jeep
# 4           4               TOYOTA           CHR             Jeep
# ...       ...                  ...           ...              ...
# 34995   34995                 FORD        Fusion            Sedan
# 34996   34996            SSANGYONG        REXTON             Jeep
# 34997   34997                  BMW           635            Sedan
# 34998   34998              HYUNDAI        Tucson             Jeep
# 34999   34999               TOYOTA        Avalon            Sedan
#
#        current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0               133000          2014            Automatic       4/5
# 1                24500          2010               Manual       4/5
# 2                31000          2016            Tiptronic       2/3
# 3               115459          2015            Automatic       4/5
# 4                18950          2019            Automatic       4/5
# ...                ...           ...                  ...       ...
# 34995            87579          2013            Automatic       4/5
# 34996           116092          2009            Automatic       4/5
# 34997            43000          2015            Tiptronic       4/5
# 34998            82139          2015            Automatic       4/5
# 34999           237178          2015            Automatic       4/5
#
#                       wheels vehicle_color vehicle_interior_color  \
# 0        Right-hand drive          Silver                  Black
# 1               Left wheel         Silver                  Black
# 2               Left wheel         Silver                  Black
# 3               Left wheel           Blue                  Black
# 4               Left wheel          Black                     NaN
# ...                      ...           ...                    ...
# 34995           Left wheel          Black                     NaN
# 34996           Left wheel         Silver                  Black
# 34997           Left wheel           Grey                   Grey
# 34998           Left wheel          White                  Black
# 34999           Left wheel           Blue                  Black
#
#                    car_vin  car_leather_interior deal_type  final_price
# 0                      NaN                     0  For Sale      3650.00
# 1                      NaN                     0  For Sale      6800.00
# 2       KMHTC6AE3GU293912                      1  For Sale      6300.00
# 3                      NaN                     1  For Sale     14488.00
# 4       JTNKHMBX7K1030253                      1  For Sale      5000.00
# ...                    ...                   ...       ...          ...
# 34995   3FA6P0K98DR308742                      1  For Sale      6000.00
# 34996                  NaN                     1  For Sale      9642.00
# 34997                  NaN                     1  For Sale     23500.00
# 34998                  NaN                     1  For Sale     12826.00
# 34999                  NaN                     1  For Sale      1050.00
#
# [34372 rows x 15 columns]

# %% [markdown]
# ### Дубликаты

# %%
# Дубликаты по всем столбцам кроме final_price
cols_for_dup = train_data.columns.to_list()[1:-1]
train_data[train_data.duplicated(subset=cols_for_dup)]
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 49         49               NISSAN          Juke             Jeep
# 109       109        MERCEDES-BENZ         E 350            Sedan
# 152       152               TOYOTA         Camry            Sedan
# 181       181               TOYOTA         Camry            Sedan
# 189       189           VOLKSWAGEN         Jetta            Sedan
# ...       ...                  ...           ...              ...
# 34978   34978               TOYOTA         Camry            Sedan
# 34984   34984                 FORD        Escape             Jeep
# 34988   34988        MERCEDES-BENZ       GLE 350             Jeep
# 34989   34989              HYUNDAI        Sonata            Sedan
# 34998   34998              HYUNDAI        Tucson             Jeep
#
#        current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 49              129128          2013            Automatic       4/5
# 109             101424          2014            Automatic       4/5
# 152             314373          2012            Automatic       4/5
# 181             109798          2014            Automatic       4/5
# 189             142515          2013            Automatic       4/5
# ...                ...           ...                  ...       ...
# 34978           115312          2014            Automatic       4/5
# 34984                0          2010            Automatic       4/5
# 34988            91493          2016            Automatic       4/5
# 34989            71466          2014            Automatic       4/5
# 34998            82139          2015            Automatic       4/5
#
#                wheels vehicle_color vehicle_interior_color  \
# 49       Left wheel          White                     NaN
# 109      Left wheel           Grey                     NaN
# 152      Left wheel           Grey                  Black
# 181      Left wheel          White                  Black
# 189      Left wheel          White                     NaN
# ...               ...           ...                    ...
# 34978    Left wheel           Grey                  Black
# 34984    Left wheel          White                     NaN
# 34988    Left wheel          Black                     NaN
# 34989    Left wheel          White                  Black
# 34998    Left wheel          White                  Black
#
#                    car_vin  car_leather_interior deal_type  final_price
# 49      JN8AF5MV2DT218035                      1  For Sale       775.00
# 109     WDDHF9CB6EA909287                      1  For Sale       200.00
# 152     4T1BD1FK2CU027785                      1  For Sale       125.00
# 181     4T1BD1FK5EU128824                      1  For Sale      1750.00
# 189     3VW467AJ8DM231647                      1  For Sale       200.00
# ...                    ...                   ...       ...          ...
# 34978   4T1BD1FK3EU118258                      1  For Sale       225.00
# 34984   1FMCU5K32AKD22226                      1  For Sale       225.00
# 34988   4JGDA5JB8GA709044                      1  For Sale       175.00
# 34989                  NaN                     1  For Sale      3591.00
# 34998                  NaN                     1  For Sale     12826.00
#
# [8636 rows x 15 columns]

# %%
# Дубликаты по всем столбцам кроме, final_price
cols_for_dup = train_data.columns.to_list()[1:]
train_data[train_data.duplicated(subset=cols_for_dup)]
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 49         49               NISSAN          Juke             Jeep
# 152       152               TOYOTA         Camry            Sedan
# 181       181               TOYOTA         Camry            Sedan
# 189       189           VOLKSWAGEN         Jetta            Sedan
# 192       192           VOLKSWAGEN         Jetta            Sedan
# ...       ...                  ...           ...              ...
# 34978   34978               TOYOTA         Camry            Sedan
# 34984   34984                 FORD        Escape             Jeep
# 34988   34988        MERCEDES-BENZ       GLE 350             Jeep
# 34989   34989              HYUNDAI        Sonata            Sedan
# 34998   34998              HYUNDAI        Tucson             Jeep
#
#        current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 49              129128          2013            Automatic       4/5
# 152             314373          2012            Automatic       4/5
# 181             109798          2014            Automatic       4/5
# 189             142515          2013            Automatic       4/5
# 192             150262          2012            Automatic       4/5
# ...                ...           ...                  ...       ...
# 34978           115312          2014            Automatic       4/5
# 34984                0          2010            Automatic       4/5
# 34988            91493          2016            Automatic       4/5
# 34989            71466          2014            Automatic       4/5
# 34998            82139          2015            Automatic       4/5
#
#                wheels vehicle_color vehicle_interior_color  \
# 49       Left wheel          White                     NaN
# 152      Left wheel           Grey                  Black
# 181      Left wheel          White                  Black
# 189      Left wheel          White                     NaN
# 192      Left wheel         Silver                     NaN
# ...               ...           ...                    ...
# 34978    Left wheel           Grey                  Black
# 34984    Left wheel          White                     NaN
# 34988    Left wheel          Black                     NaN
# 34989    Left wheel          White                  Black
# 34998    Left wheel          White                  Black
#
#                    car_vin  car_leather_interior deal_type  final_price
# 49      JN8AF5MV2DT218035                      1  For Sale       775.00
# 152     4T1BD1FK2CU027785                      1  For Sale       125.00
# 181     4T1BD1FK5EU128824                      1  For Sale      1750.00
# 189     3VW467AJ8DM231647                      1  For Sale       200.00
# 192     3VW467AJ2CM122826                      1  For Sale       200.00
# ...                    ...                   ...       ...          ...
# 34978   4T1BD1FK3EU118258                      1  For Sale       225.00
# 34984   1FMCU5K32AKD22226                      1  For Sale       225.00
# 34988   4JGDA5JB8GA709044                      1  For Sale       175.00
# 34989                  NaN                     1  For Sale      3591.00
# 34998                  NaN                     1  For Sale     12826.00
#
# [8045 rows x 15 columns]

# %% [markdown]
# ### Не удаляю никакие дубликаты, сильно ухудшается метрика mae

# %%
# Все таки удаляю полные дубликаты по всем столбцам в т.ч. и целевому final_price
# train_data = train_data.drop_duplicates(subset=cols_for_dup)
# train_data

# %% [markdown]
# Внимание на год выпуска, пробег и цену авто.\
# В годе выпуска нашал в тренировочных данных одну запись с нулевым годом.\
# Она полностью кривая, там везде пусто. ЕЕ удалить.\
#
# Так же нашел две записи с нулевой ценой.\
# Цену отдельно проверяю, надо проверить на предмет нормальности данных.

# %% [markdown]
# ### Изучаю год выпуска авто

# %%
train_data['vehicle_year'].value_counts()
# Out:
# 2012    3871
# 2013    3707
# 2014    3584
# 2011    2752
# 2015    2605
#         ...
# 1978       1
# 1970       1
# 1968       1
# 1975       1
# 0          1
# Name: vehicle_year, Length: 66, dtype: int64

# %%
test_data['vehicle_year'].value_counts()
# Out:
# 2012    1193
# 2013    1153
# 2014    1100
# 2015     836
# 2011     836
# 2010     751
# 2016     750
# 2017     525
# 2008     488
# 2009     329
# 2018     318
# 2007     254
# 2003     229
# 2004     218
# 2005     215
# 2019     201
# 2006     188
# 2000     173
# 2002     165
# 2001     159
# 1999     128
# 1998     112
# 1997      76
# 1995      68
# 1996      64
# 1994      29
# 2020      25
# 1992      25
# 1990      17
# 1993      16
# 1989      10
# 1988       7
# 1986       7
# 1991       4
# 1985       4
# 1984       3
# 1978       2
# 1956       2
# 1953       2
# 1987       2
# 1980       2
# 1968       1
# 1983       1
# 1970       1
# 1947       1
# 1955       1
# 1957       1
# 1973       1
# 1981       1
# 1966       1
# 1974       1
# 0          1
# Name: vehicle_year, dtype: int64

# %%
# Вижу по одной записи с нулевым годом выпуска в обоих выборках
# Смотрю на эти записи

# %%
train_data[train_data['vehicle_year'] == 0]
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 17918   17918                  NaN           NaN              NaN
#
#        current_mileage  vehicle_year vehicle_gearbox_type doors_cnt wheels  \
# 17918                0             0                  NaN       NaN    NaN
#
#       vehicle_color vehicle_interior_color car_vin  car_leather_interior  \
# 17918           NaN                    NaN     NaN                     0
#
#       deal_type  final_price
# 17918  For Sale         0.00

# %%
test_data[test_data['vehicle_year'] == 0]
# Out:
#       row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 2254   37254                  NaN           NaN              NaN
#
#       current_mileage  vehicle_year vehicle_gearbox_type doors_cnt wheels  \
# 2254                0             0                  NaN       NaN    NaN
#
#      vehicle_color vehicle_interior_color car_vin  car_leather_interior  \
# 2254           NaN                    NaN     NaN                     0
#
#      deal_type
# 2254  For Sale

# %% [markdown]
# Удаляю эту запись из тренировочной выборки, она искажает обучение.\
# Из тестовой выборки ничего удалить не могу, \
# поэтому запоминаю row_ID=37254 и в итоговом сабмишене вручную ставлю ноль.

# %%
# По индексу эту запись удаляю из тренировочной выборки
ind = train_data[train_data['vehicle_year'] == 0].index
train_data.drop(ind, inplace=True)

# %%
train_data['vehicle_year'].describe()
# Out:
# count   34371.00
# mean     2010.77
# std         5.83
# min      1940.00
# 25%      2009.00
# 50%      2012.00
# 75%      2014.00
# max      2020.00
# Name: vehicle_year, dtype: float64

# %%
# Смотрю на текущее распределение года выпуска
# Вижу вылеты за пределами усов ниже 1998г примерно
hd.Hist_and_Box_Plots(train_data, 'vehicle_year')

# %%
# С помощью группировки по годам посчитаю количество машин выпущенному в каждом году
group_by_year = train_data.groupby('vehicle_year').agg({'vehicle_year': 'count'})
group_by_year.columns = ['Vehicle count']
group_by_year
# Out:
#               Vehicle count
# vehicle_year
# 1940                      1
# 1941                      1
# 1943                      2
# 1951                      1
# 1953                      3
# ...                     ...
# 2016                   2518
# 2017                   1657
# 2018                   1003
# 2019                    645
# 2020                    103
#
# [65 rows x 1 columns]

# %%
fig = plt.figure(figsize=(16, 10))
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(group_by_year.index, group_by_year['Vehicle count'])
ax.set_title('Количество машин по годам');

# %% [markdown]
# ### Преобразую год выпуска в возраст машины

# %%
def age_feature(data):
    data['vehicle_age'] = 2022 - data['vehicle_year']
    data = data.drop(columns=['vehicle_year'], axis=1)
    return data

# %%
# %%time
train_data = age_feature(train_data)
test_data = age_feature(test_data)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 6.01 ms

# %%
# Смотрю как выглядят распределения возраста
hd.Hist_and_Box_Plots(train_data, 'vehicle_age')

# %%
# Использую метод Тьюки
iqr_info, iqr_outliers, iqr_clean_train_data = hd.outliers_iqr(train_data, 'vehicle_age', log_scale=False, left=1.5, right=1.2)
iqr_info
# Out:
# 'Выбросы: 3575 строк (10.40%).'

# %%
# Смотрю как выглядят распределения возраста для отчищенных данных по методу тьюки
hd.Hist_and_Box_Plots(iqr_clean_train_data, 'vehicle_age')

# %%
# Использую метод 3х сигм
z_info, z_outliers, z_clean_train_data = hd.outliers_z_score(train_data, 'vehicle_age', log_scale=False, left=3, right=1)
z_info
# Out:
# 'Выбросы: 4923 строк (14.32%).'

# %%
# Смотрю как выглядят распределения возраста для отчищенных данных по методу 3х сигм
hd.Hist_and_Box_Plots(z_clean_train_data, 'vehicle_age')

# %% [markdown]
# ### По методу тьюки убираю вылеты из тренировочной выборки

# %%
train_data = iqr_clean_train_data

# %% [markdown]
# ### Анализ целевой переменной final_price

# %%
train_data['final_price'].describe()
# Out:
# count     30130.00
# mean       6071.37
# std       49114.84
# min           0.00
# 25%        1450.00
# 50%        4500.00
# 75%        7568.00
# max     8388607.00
# Name: final_price, dtype: float64

# %% [markdown]
# Есть машина с нулевой ценой и с ценой в 8млн!

# %%
# Смотрю как выглядят распределения цены
# Это просто ужас! Данные надо вычищать!
hd.Hist_and_Box_Plots(train_data, 'final_price')

# %%
# Странные машины с ценой до 100 долл, в т.ч. и с нулевой ценой
train_data[train_data['final_price'] < 100]
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 12         12                LEXUS        GX 470             Jeep
# 24         24                  BMW            X5             Jeep
# 75         75               TOYOTA         Prius        Hatchback
# 94         94              HYUNDAI        Sonata            Sedan
# 239       239               TOYOTA        Tacoma             Jeep
# ...       ...                  ...           ...              ...
# 34823   34823                LEXUS        GS 350            Sedan
# 34827   34827        MERCEDES-BENZ         E 350            Sedan
# 34868   34868                LEXUS        RX 450             Jeep
# 34938   34938               TOYOTA         Prius        Hatchback
# 34994   34994                BUICK         Regal            Sedan
#
#        current_mileage vehicle_gearbox_type doors_cnt          wheels  \
# 12              252890            Automatic       4/5    Left wheel
# 24              296395            Automatic       4/5    Left wheel
# 75              169301            Automatic       4/5    Left wheel
# 94              224349            Automatic       4/5    Left wheel
# 239              34472            Automatic       4/5    Left wheel
# ...                ...                  ...       ...             ...
# 34823           125326            Automatic       4/5    Left wheel
# 34827           205922            Automatic       4/5    Left wheel
# 34868           311949            Automatic       4/5    Left wheel
# 34938            30531            Automatic       4/5    Left wheel
# 34994           229677            Automatic       4/5    Left wheel
#
#       vehicle_color vehicle_interior_color              car_vin  \
# 12             Red                     NaN   JTJBT20X780149121
# 24            Grey                     NaN   5UXZW0C57CL664603
# 75           White                  Black    JTDKN3DU2D5580904
# 94            Grey                     NaN   KMHEC4A49BA004756
# 239             NaN                 Black    3TMAZ5CNXGM011030
# ...             ...                    ...                  ...
# 34823        White                     NaN   JTHBE1BL0E5039946
# 34827        Black                     NaN   WDBUF87X49B402962
# 34868       Silver                     NaN   JTJZB1BA3A2000123
# 34938       Silver                   Grey                   NaN
# 34994       Silver                  Black                   NaN
#
#        car_leather_interior deal_type  final_price  vehicle_age
# 12                        1  For Sale        20.00           14
# 24                        1  For Sale        50.00           10
# 75                        1  For Sale        50.00            9
# 94                        1  For Sale        80.00           11
# 239                       1  For Sale        15.00            6
# ...                     ...       ...          ...          ...
# 34823                     1  For Sale        60.00            8
# 34827                     1  For Sale        20.00           13
# 34868                     1  For Sale        90.00           12
# 34938                     1  For Sale        25.00           10
# 34994                     1  For Sale        90.00           11
#
# [1116 rows x 15 columns]

# %%
# Машины дороже 200т, очевидные вылеты
train_data[train_data['final_price'] > 200_000]
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 3877     3877           VOLKSWAGEN          Golf            Sedan
# 12136   12136                  BMW           328            Sedan
#
#        current_mileage vehicle_gearbox_type doors_cnt          wheels  \
# 3877              7676            Tiptronic       4/5    Left wheel
# 12136           246000            Automatic       4/5    Left wheel
#
#       vehicle_color vehicle_interior_color car_vin  car_leather_interior  \
# 3877           Red                 Golden      NaN                     0
# 12136     Sky blue                 Yellow      NaN                     1
#
#       deal_type  final_price  vehicle_age
# 3877   For Sale   8388607.00           15
# 12136  For Sale   1111111.00           14

# %%
# Избавляюсь вручную от этих записей
train_data = train_data[train_data['final_price'] <= 200_000]
train_data = train_data[train_data['final_price'] > 0]

# %%
# Стало лучше, но все-равно сильный правый перекос
hd.Hist_and_Box_Plots(train_data, 'final_price')

# %%
train_data['final_price'].describe()
# Out:
# count    30127.00
# mean      5756.66
# std       6280.16
# min          1.00
# 25%       1450.00
# 50%       4500.00
# 75%       7568.00
# max     200000.00
# Name: final_price, dtype: float64

# %%
# Использую метод Тьюки для борьбы с выбросами в final_price
iqr_info, iqr_outliers, iqr_clean_train_data = hd.outliers_iqr(train_data, 'final_price', log_scale=False, left=1.5, right=1)
iqr_info
# Out:
# 'Выбросы: 2670 строк (8.86%).'

# %%
# Стало лучше, но все-равно сильный правый перекос
hd.Hist_and_Box_Plots(iqr_clean_train_data, 'final_price')

# %%
# Использую метод 3х сигм
z_info, z_outliers, z_clean_train_data = hd.outliers_z_score(train_data, 'final_price', log_scale=False, left=3, right=1)
z_info
# Out:
# 'Выбросы: 3610 строк (11.98%).'

# %%
# Стало лучше, но все-равно сильный правый перекос
hd.Hist_and_Box_Plots(z_clean_train_data, 'final_price')

# %%
# Чищу данные по методу тьюки. Пока не чищу.
# train_data = iqr_clean_train_data

# %%
train_data['final_price'].describe()
# Out:
# count    30127.00
# mean      5756.66
# std       6280.16
# min          1.00
# 25%       1450.00
# 50%       4500.00
# 75%       7568.00
# max     200000.00
# Name: final_price, dtype: float64

# %% [markdown]
# ### Изучаю пробег

# %%
# C нулевым пробегом все ок просто полностью новая машина. А вот пробег непонятно какой 2_147_483_647. Два миллиарда миль!
train_data['current_mileage'].describe()
# Out:
# count        30127.00
# mean        861409.36
# std       38015990.42
# min              0.00
# 25%          71873.50
# 50%         124912.00
# 75%         183217.50
# max     2147483647.00
# Name: current_mileage, dtype: float64

# %%
train_data[train_data['current_mileage'] == 0]
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 18         18               NISSAN         Tiida        Hatchback
# 37         37            CHEVROLET          Volt        Hatchback
# 65         65               TOYOTA        Tacoma            Sedan
# 84         84        MERCEDES-BENZ         E 400            Sedan
# 141       141                 FORD        Escape             Jeep
# ...       ...                  ...           ...              ...
# 34846   34846               NISSAN          Juke             Jeep
# 34847   34847               TOYOTA        Tundra            Sedan
# 34931   34931        MERCEDES-BENZ         E 300            Sedan
# 34959   34959        MERCEDES-BENZ       GLA 250             Jeep
# 34984   34984                 FORD        Escape             Jeep
#
#        current_mileage vehicle_gearbox_type doors_cnt          wheels  \
# 18                   0            Automatic       4/5    Left wheel
# 37                   0            Automatic       4/5    Left wheel
# 65                   0            Automatic       4/5    Left wheel
# 84                   0            Automatic       NaN    Left wheel
# 141                  0            Automatic       4/5    Left wheel
# ...                ...                  ...       ...             ...
# 34846                0            Automatic       NaN    Left wheel
# 34847                0            Automatic       4/5    Left wheel
# 34931                0            Automatic       NaN    Left wheel
# 34959                0            Automatic       NaN    Left wheel
# 34984                0            Automatic       4/5    Left wheel
#
#       vehicle_color vehicle_interior_color              car_vin  \
# 18          Silver                  Black                   NaN
# 37            Grey                     NaN   1G1RH6E40DU104154
# 65          Silver                  Black    3TMJU4GN9EM157368
# 84           Green                     NaN   WDD1K6FB4JF033937
# 141           Grey                     NaN   1FMCU593X9KB01247
# ...             ...                    ...                  ...
# 34846          Red                     NaN   JN8AF5MR2HT702375
# 34847        White                  Black    5TFHW5F11EX335880
# 34931        Black                     NaN   WDDZF4JB6JA349680
# 34959        White                     NaN   WDCTG4GB4JJ443295
# 34984        White                     NaN   1FMCU5K32AKD22226
#
#        car_leather_interior deal_type  final_price  vehicle_age
# 18                        1  For Sale      3200.00           17
# 37                        1  For Sale       100.00            9
# 65                        1  For Sale      2100.00            8
# 84                        1  For Sale      8300.00            4
# 141                       1  For Sale       100.00           13
# ...                     ...       ...          ...          ...
# 34846                     1  For Sale       825.00            5
# 34847                     1  For Sale      1050.00            8
# 34931                     1  For Sale       150.00            4
# 34959                     1  For Sale     14000.00            4
# 34984                     1  For Sale       225.00           12
#
# [885 rows x 15 columns]

# %%
train_data[train_data['current_mileage'] == 2147483647]
# Out:
#        row_ID vehicle_manufacturer    vehicle_model vehicle_category  \
# 8940     8940              HYUNDAI           Sonata            Sedan
# 10885   10885            CHEVROLET            Cruze            Sedan
# 13926   13926               NISSAN             Note        Hatchback
# 19296   19296        MERCEDES-BENZ         Sprinter         Microbus
# 26303   26303                 FORD  Tourneo Connect      Goods wagon
# 29929   29929               NISSAN            Tiida        Hatchback
# 31486   31486                  VAZ             2101            Sedan
# 32072   32072              PORSCHE          Cayenne             Jeep
# 32649   32649              HYUNDAI           Sonata            Sedan
#
#        current_mileage vehicle_gearbox_type doors_cnt                 wheels  \
# 8940        2147483647            Tiptronic       4/5           Left wheel
# 10885       2147483647            Automatic       4/5           Left wheel
# 13926       2147483647             Variator       4/5    Right-hand drive
# 19296       2147483647            Tiptronic       2/3           Left wheel
# 26303       2147483647               Manual        >5           Left wheel
# 29929       2147483647            Automatic       4/5    Right-hand drive
# 31486       2147483647               Manual       4/5           Left wheel
# 32072       2147483647            Tiptronic       4/5           Left wheel
# 32649       2147483647            Automatic       4/5           Left wheel
#
#          vehicle_color vehicle_interior_color car_vin  car_leather_interior  \
# 8940           Golden                 Yellow      NaN                     0
# 10885           Beige                  Black      NaN                     0
# 13926          Silver                  Black      NaN                     0
# 19296           White                  Black      NaN                     1
# 26303           White                   Grey      NaN                     0
# 29929           Black                  Black      NaN                     1
# 31486           Green                  Black      NaN                     0
# 32072           Black                  Brown      NaN                     1
# 32649   Carnelian red                  Beige      NaN                     1
#
#       deal_type  final_price  vehicle_age
# 8940   For Sale      5300.00            9
# 10885  For Sale      4700.00            9
# 13926  For Sale      2073.00           15
# 19296  For Sale     16800.00           14
# 26303  For Sale      4700.00           12
# 29929  For Sale      2200.00           17
# 31486  For Sale       351.00            2
# 32072  For Sale      4300.00           18
# 32649  For Sale      6750.00            9

# %%
# удаляю этот непонятный пробег
train_data = train_data[train_data['current_mileage'] < 2147483647]

# %%
train_data
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0           0               TOYOTA        Aqua s            Sedan
# 1           1        MERCEDES-BENZ         C 220            Sedan
# 2           2              HYUNDAI      Veloster        Hatchback
# 3           3              HYUNDAI      Santa FE             Jeep
# 4           4               TOYOTA           CHR             Jeep
# ...       ...                  ...           ...              ...
# 34995   34995                 FORD        Fusion            Sedan
# 34996   34996            SSANGYONG        REXTON             Jeep
# 34997   34997                  BMW           635            Sedan
# 34998   34998              HYUNDAI        Tucson             Jeep
# 34999   34999               TOYOTA        Avalon            Sedan
#
#        current_mileage vehicle_gearbox_type doors_cnt                 wheels  \
# 0               133000            Automatic       4/5    Right-hand drive
# 1                24500               Manual       4/5           Left wheel
# 2                31000            Tiptronic       2/3           Left wheel
# 3               115459            Automatic       4/5           Left wheel
# 4                18950            Automatic       4/5           Left wheel
# ...                ...                  ...       ...                    ...
# 34995            87579            Automatic       4/5           Left wheel
# 34996           116092            Automatic       4/5           Left wheel
# 34997            43000            Tiptronic       4/5           Left wheel
# 34998            82139            Automatic       4/5           Left wheel
# 34999           237178            Automatic       4/5           Left wheel
#
#       vehicle_color vehicle_interior_color              car_vin  \
# 0           Silver                  Black                   NaN
# 1           Silver                  Black                   NaN
# 2           Silver                  Black    KMHTC6AE3GU293912
# 3             Blue                  Black                   NaN
# 4            Black                     NaN   JTNKHMBX7K1030253
# ...             ...                    ...                  ...
# 34995        Black                     NaN   3FA6P0K98DR308742
# 34996       Silver                  Black                   NaN
# 34997         Grey                   Grey                   NaN
# 34998        White                  Black                   NaN
# 34999         Blue                  Black                   NaN
#
#        car_leather_interior deal_type  final_price  vehicle_age
# 0                         0  For Sale      3650.00            8
# 1                         0  For Sale      6800.00           12
# 2                         1  For Sale      6300.00            6
# 3                         1  For Sale     14488.00            7
# 4                         1  For Sale      5000.00            3
# ...                     ...       ...          ...          ...
# 34995                     1  For Sale      6000.00            9
# 34996                     1  For Sale      9642.00           13
# 34997                     1  For Sale     23500.00            7
# 34998                     1  For Sale     12826.00            7
# 34999                     1  For Sale      1050.00            7
#
# [30118 rows x 15 columns]

# %%
# Когда одна и та же цифра от 1 до 9 повторояется более 5 раз
rx = r'[1]{5,}|[2]{5,}|[3]{5,}|[4]{5,}|[5]{5,}|[6]{5,}|[7]{5,}|[8]{5,}|[9]{5,}'

# %%
for_del = train_data[train_data['current_mileage'].astype('str').str.match(rx)]
for_del
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 538       538                HONDA           FIT            Sedan
# 720       720            CHEVROLET       Equinox             Jeep
# 1283     1283               TOYOTA         Prius        Hatchback
# 1395     1395        MERCEDES-BENZ          Vito      Goods wagon
# 1696     1696                 OPEL         Combo      Goods wagon
# ...       ...                  ...           ...              ...
# 33107   33107               TOYOTA       Caldina            Sedan
# 33148   33148                HONDA           FIT        Hatchback
# 33204   33204                LEXUS       HS 250h            Sedan
# 33643   33643           MITSUBISHI          Colt        Hatchback
# 34690   34690        MERCEDES-BENZ         C 300            Sedan
#
#        current_mileage vehicle_gearbox_type doors_cnt                 wheels  \
# 538             111111            Automatic       4/5           Left wheel
# 720              11111            Automatic       4/5           Left wheel
# 1283            111111            Automatic       4/5           Left wheel
# 1395            555555               Manual       4/5           Left wheel
# 1696             11111               Manual       2/3           Left wheel
# ...                ...                  ...       ...                    ...
# 33107           111111            Automatic       4/5    Right-hand drive
# 33148           999999             Variator       4/5    Right-hand drive
# 33204            11111             Variator       4/5           Left wheel
# 33643            55555            Tiptronic       4/5    Right-hand drive
# 34690           111111            Tiptronic       4/5           Left wheel
#
#       vehicle_color vehicle_interior_color              car_vin  \
# 538           Grey                  Black                   NaN
# 720         Silver                   Grey                   NaN
# 1283         White                  Black                   NaN
# 1395         White                  Black                   NaN
# 1696         White                  Black                   NaN
# ...             ...                    ...                  ...
# 33107        White                  Black                   NaN
# 33148        Green                  Beige                   NaN
# 33204       Silver                  White    JTHBB1BA6A2012446
# 33643        Black                  Black                   NaN
# 34690        Black                  Black                   NaN
#
#        car_leather_interior deal_type  final_price  vehicle_age
# 538                       0  For Sale      2800.00           14
# 720                       0  For Sale      1052.00           17
# 1283                      1  For Sale         6.00           14
# 1395                      0  For Sale      3000.00           18
# 1696                      0  For Sale      1754.00           15
# ...                     ...       ...          ...          ...
# 33107                     0  For Sale      2600.00           18
# 33148                     0  For Sale      3600.00           11
# 33204                     1  For Sale      3650.00           12
# 33643                     0  For Sale      2500.00           17
# 34690                     1  For Sale      6500.00           12
#
# [99 rows x 15 columns]

# %%
# Удалил записи с значениями пробега состоящими из одного символа на повторе
train_data.drop(for_del.index, inplace=True)

# %%
train_data['current_mileage'].describe()
# Out:
# count      30019.00
# mean      145425.47
# std       429788.24
# min            0.00
# 25%        71887.00
# 50%       125000.00
# 75%       183000.00
# max     43688569.00
# Name: current_mileage, dtype: float64

# %%
# 43 миллиона миль
train_data[train_data['current_mileage'] > 1_000_000]
# Out:
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 613       613               SUBARU        Legacy        Universal
# 824       824               SUZUKI         Swift        Hatchback
# 953       953                  BMW           335            Sedan
# 3346     3346               TOYOTA         Prius        Hatchback
# 3425     3425                HONDA           FIT        Hatchback
# 3679     3679               TOYOTA         Camry            Sedan
# 6481     6481               TOYOTA         Camry            Sedan
# 8509     8509           VOLKSWAGEN            CC            Sedan
# 10483   10483           VOLKSWAGEN        Passat            Sedan
# 10629   10629               TOYOTA         Prius        Hatchback
# 11521   11521                DODGE       Caliber        Hatchback
# 13559   13559               TOYOTA          VOXY          Minivan
# 14090   14090                 FORD       Transit         Microbus
# 14237   14237           VOLKSWAGEN        Passat            Sedan
# 16034   16034               SUBARU        Legacy            Sedan
# 17039   17039        MERCEDES-BENZ         Smart        Hatchback
# 17211   17211              HYUNDAI           I30        Universal
# 17955   17955               TOYOTA         Prius            Sedan
# 18935   18935               SUBARU       Outback             Jeep
# 19487   19487                  BMW  X6 3.5 turbo             Jeep
# 19550   19550                 OPEL         Astra      Goods wagon
# 19589   19589                  BMW            X5             Jeep
# 20111   20111               TOYOTA         Prius        Hatchback
# 21529   21529               TOYOTA       4Runner             Jeep
# 22554   22554               TOYOTA         Prius        Hatchback
# 23689   23689                HONDA         Civic            Sedan
# 25905   25905              HYUNDAI       Elantra            Sedan
# 26952   26952              HYUNDAI       Elantra            Sedan
# 27831   27831                HONDA         Civic            Sedan
# 31199   31199        MERCEDES-BENZ     E 350 amg            Sedan
# 32745   32745              HYUNDAI        Sonata            Sedan
# 33703   33703               TOYOTA         Camry            Sedan
# 34026   34026              HYUNDAI       Elantra            Sedan
#
#        current_mileage vehicle_gearbox_type doors_cnt                 wheels  \
# 613            1980000            Tiptronic       4/5    Right-hand drive
# 824           23000000               Manual       4/5    Right-hand drive
# 953           43688569            Tiptronic       4/5           Left wheel
# 3346           1888000             Variator       4/5           Left wheel
# 3425          11200000            Automatic       4/5    Right-hand drive
# 3679           1500000            Tiptronic       4/5           Left wheel
# 6481           1440000            Automatic       4/5           Left wheel
# 8509           2864648            Tiptronic       4/5           Left wheel
# 10483          2500000               Manual       4/5           Left wheel
# 10629          2696320            Automatic       4/5           Left wheel
# 11521          1100000            Automatic       4/5           Left wheel
# 13559         15500000            Tiptronic       4/5    Right-hand drive
# 14090          1440000               Manual       4/5           Left wheel
# 14237          8400000            Tiptronic       4/5           Left wheel
# 16034         20000000            Tiptronic       4/5    Right-hand drive
# 17039          1000900            Tiptronic       4/5    Right-hand drive
# 17211          1711230               Manual       4/5           Left wheel
# 17955          1360000            Automatic       4/5           Left wheel
# 18935          1110000            Tiptronic       4/5    Right-hand drive
# 19487          1280000            Automatic       4/5           Left wheel
# 19550          1800000               Manual       4/5           Left wheel
# 19589          7789999            Automatic       4/5           Left wheel
# 20111          2005000             Variator       4/5           Left wheel
# 21529          2200000            Automatic        >5           Left wheel
# 22554          1500000            Automatic       4/5           Left wheel
# 23689          2432000             Variator       4/5           Left wheel
# 25905          1456394            Tiptronic       4/5           Left wheel
# 26952          1678000            Automatic       4/5           Left wheel
# 27831         43678986             Variator       4/5    Right-hand drive
# 31199          1568000            Tiptronic       4/5           Left wheel
# 32745          1398451             Variator       4/5           Left wheel
# 33703          1232725            Tiptronic       4/5           Left wheel
# 34026          1624000            Tiptronic       4/5           Left wheel
#
#       vehicle_color vehicle_interior_color              car_vin  \
# 613          Black                  Black                   NaN
# 824         Silver                  Beige                   NaN
# 953         Silver                  Black                   NaN
# 3346         White                 Golden                   NaN
# 3425          Blue                  Black                   NaN
# 3679         White                  White                   NaN
# 6481        Silver                  Black                   NaN
# 8509        Silver                  Black                   NaN
# 10483        Black                   Grey                   NaN
# 10629         Grey                   Grey                   NaN
# 11521        Black                  White                   NaN
# 13559        White                  Black                   NaN
# 14090        White                  Beige                   NaN
# 14237        White                  Black                   NaN
# 16034        Black                  Black                   NaN
# 17039        Black                 Orange                   NaN
# 17211        Black                  Black                   NaN
# 17955       Silver                  Black                   NaN
# 18935         Blue                  Black                   NaN
# 19487        Black                  Black                   NaN
# 19550       Silver                   Grey                   NaN
# 19589        Brown                  Brown                   NaN
# 20111        White                  Beige                   NaN
# 21529        Black                  White                   NaN
# 22554        White                   Grey                   NaN
# 23689         Grey                   Blue                   NaN
# 25905        White                  Beige                   NaN
# 26952       Silver                  Black                   NaN
# 27831       Silver                   Blue                   NaN
# 31199        Black                  Black    WDDHF8JB4DA667160
# 32745       Silver                   Grey                   NaN
# 33703        Black                  Black                   NaN
# 34026        White                   Grey                   NaN
#
#        car_leather_interior deal_type  final_price  vehicle_age
# 613                       0  For Sale      2200.00           17
# 824                       0  For Sale       733.00           17
# 953                       1  For Sale      4800.00           15
# 3346                      1  For Sale      6200.00           12
# 3425                      0  For Sale      2950.00           11
# 3679                      1  For Sale        22.00           12
# 6481                      0  For Sale      5100.00            8
# 8509                      1  For Sale      5500.00           11
# 10483                     1  For Sale      1350.00           18
# 10629                     1  For Sale      4500.00           17
# 11521                     1  For Sale      4300.00           12
# 13559                     0  For Sale        32.00           16
# 14090                     0  For Sale      3500.00           17
# 14237                     1  For Sale      6000.00            9
# 16034                     1  For Sale      2700.00           18
# 17039                     0  For Sale      1600.00           18
# 17211                     0  For Sale      3000.00           13
# 17955                     0  For Sale      6300.00           10
# 18935                     0  For Sale      3400.00           16
# 19487                     1  For Sale     23500.00            9
# 19550                     0  For Sale      2300.00           18
# 19589                     1  For Sale      5000.00           17
# 20111                     1  For Sale      5600.00           13
# 21529                     1  For Sale      8800.00           15
# 22554                     1  For Sale      5700.00           11
# 23689                     0  For Sale      4200.00           14
# 25905                     0  For Sale      5300.00            9
# 26952                     1  For Sale      3918.00           15
# 27831                     0  For Sale      2400.00           16
# 31199                     1  For Sale     12700.00            9
# 32745                     0  For Sale      4600.00           12
# 33703                     1  For Sale      9500.00            7
# 34026                     0  For Sale      8500.00            6

# %%
# Использую метод Тьюки для борьбы с выбросами в final_price
iqr_info, iqr_outliers, iqr_clean_train_data = hd.outliers_iqr(train_data, 'current_mileage', log_scale=False, left=1.5, right=1)
iqr_info
# Out:
# 'Выбросы: 1868 строк (6.22%).'

# %%
# Попробую так убрать выбросы больше 300т миль
hd.Hist_and_Box_Plots(iqr_clean_train_data, 'current_mileage')

# %%
train_data = iqr_clean_train_data

# %% [markdown]
# ### Привожу целевую переменную к целому типу, это упростит создание модели

# %%
train_data[TARGET_NAME] = train_data[TARGET_NAME].astype('int')

# %% [markdown]
# ### 0.6. Data splitting for train-holdout
# As we have only one file with target values, we can split it into 80%-20% for holdout usage:

# %%
tr_data, te_data = train_test_split(
    train_data, 
    test_size=TEST_SIZE, 
    random_state=RANDOM_STATE
)

print(f'Data splitted. Parts sizes: tr_data = {tr_data.shape}, te_data = {te_data.shape}')

tr_data.head()
# Out:
# Data splitted. Parts sizes: tr_data = (22520, 15), te_data = (5631, 15)
#        row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 5504     5504           VOLKSWAGEN         Jetta            Sedan
# 32404   32404               TOYOTA         RAV 4             Jeep
# 5261     5261            CHEVROLET         Cruze            Sedan
# 2310     2310               TOYOTA         Prius        Hatchback
# 6036     6036              HYUNDAI        Tucson             Jeep
#
#        current_mileage vehicle_gearbox_type doors_cnt          wheels  \
# 5504             78829            Automatic       4/5    Left wheel
# 32404            44360            Automatic       4/5    Left wheel
# 5261            154148            Automatic       4/5    Left wheel
# 2310            162000            Automatic       4/5    Left wheel
# 6036            166291            Automatic       4/5    Left wheel
#
#       vehicle_color vehicle_interior_color              car_vin  \
# 5504         White                     NaN   3VW267AJ0GM402306
# 32404         Blue                  Black                   NaN
# 5261         Black                  Black                   NaN
# 2310         White                 Yellow                   NaN
# 6036         Black                  Black                   NaN
#
#        car_leather_interior deal_type  final_price  vehicle_age
# 5504                      1  For Sale          200            6
# 32404                     1  For Sale          175            4
# 5261                      1  For Sale         4345           11
# 2310                      1  For Sale         3800           12
# 6036                      1  For Sale         7795           12

# %% [markdown]
# # 1. Task definition

# %% [markdown]
# ### 1.1. Task type
#
# On the cell below we create Task object - the class to setup what task LightAutoML model should solve with specific loss and metric if necessary (more info can be found [here](https://lightautoml.readthedocs.io/en/latest/pages/modules/generated/lightautoml.tasks.base.Task.html#lightautoml.tasks.base.Task) in our documentation):

# %%
task = Task('reg', loss = 'mae', metric = 'mae')

# %% [markdown]
# ### 1.2. Feature roles setup

# %% [markdown]
# To solve the task, we need to setup columns roles. The **only role you must setup is target role**, everything else (drop, numeric, categorical, group, weights etc.) is up to user - LightAutoML models have automatic columns typization inside:

# %%
roles = {
    'target': TARGET_NAME,
    'drop': ['row_ID', 'deal_type']
}

# %% [markdown]
# ### 1.3. LightAutoML model creation - TabularAutoML preset

# %%
# automl = TabularAutoML(
automl = TabularUtilizedAutoML(
    task = task, 
    timeout = TIMEOUT,
    cpu_limit = N_THREADS,
    reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE}
)

# %% [markdown]
# # 2. AutoML training

# %% [markdown]
# To run autoML training use fit_predict method:
# - `train_data` - Dataset to train.
# - `roles` - Roles dict.
# - `verbose` - Controls the verbosity: the higher, the more messages.
#         <1  : messages are not displayed;
#         >=1 : the computation process for layers is displayed;
#         >=2 : the information about folds processing is also displayed;
#         >=3 : the hyperparameters optimization process is also displayed;
#         >=4 : the training process for every algorithm is displayed;
#
# Note: out-of-fold prediction is calculated during training and returned from the fit_predict method

# %%
# %%time 
oof_pred = automl.fit_predict(tr_data, roles = roles, verbose = 1)
# Out:
# [17:27:41] Start automl utilizator with listed constraints:
# [17:27:41] - time: 1800.00 seconds
# [17:27:41] - CPU: 4 cores
# [17:27:41] - memory: 16 GB
#
# [17:27:41] If one preset completes earlier, next preset configuration will be started
#
# [17:27:41] ==================================================
# [17:27:41] Start 0 automl preset configuration:
# [17:27:41] c:\Users\avvoy\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_0_sel_type_0.yml, random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# [17:27:41] Stdout logging level is INFO.
# [17:27:41] Task: reg
#
# [17:27:41] Start automl preset with listed constraints:
# [17:27:41] - time: 1800.00 seconds
# [17:27:41] - CPU: 4 cores
# [17:27:41] - memory: 16 GB
#
# [17:27:41] Train data shape: (22520, 15)
#
# [17:27:43] Layer 1 train process start. Time left 1797.99 secs
# [17:27:44] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# [17:27:56] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -2992.659887417849
# [17:27:56] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [17:27:56] Time left 1785.09 secs
#
# [17:27:57] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# [17:28:11] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1869.605537284204
# [17:28:11] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [17:28:11] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 300.00 secs
# [17:28:11] Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# [17:33:15] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# [17:33:15] Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# [17:34:15] Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -1724.9269204785462
# [17:34:15] Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# [17:34:15] Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
# [17:34:37] Fitting Lvl_0_Pipe_1_Mod_2_CatBoost finished. score = -1879.9966136404241
# [17:34:37] Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# [17:34:37] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ... Time budget is 300.00 secs
# [17:39:41] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# [17:39:41] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# [17:40:18] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1828.069370693519
# [17:40:18] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [17:40:18] Time left 1042.99 secs
#
# [17:40:18] Layer 1 training completed.
#
# [17:40:18] Blending: optimization starts with equal weights and score -1932.314975062145
# [17:40:18] Blending: iteration 0: score = -1724.3933286722981, weights = [0.         0.         0.9405463  0.         0.05945371]
# [17:40:18] Blending: iteration 1: score = -1724.3933286722981, weights = [0.         0.         0.9405463  0.         0.05945371]
# [17:40:18] Blending: no score update. Terminated
#
# [17:40:18] Automl preset training completed in 757.09 seconds
#
# [17:40:18] Model description:
# Final prediction for new objects (level 0) =
# 	 0.94055 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 	 0.05945 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
#
# [17:40:18] ==================================================
# [17:40:18] Start 1 automl preset configuration:
# [17:40:18] c:\Users\avvoy\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_1_sel_type_1.yml, random state: {'reader_params': {'random_state': 43}, 'general_params': {'return_all_predictions': False}}
# [17:40:18] Stdout logging level is INFO.
# [17:40:18] Task: reg
#
# [17:40:18] Start automl preset with listed constraints:
# [17:40:18] - time: 1042.89 seconds
# [17:40:18] - CPU: 4 cores
# [17:40:18] - memory: 16 GB
#
# [17:40:18] Train data shape: (22520, 15)
#
# [17:40:20] Layer 1 train process start. Time left 1040.95 secs
# [17:40:21] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# [17:40:31] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -2753.9689061863596
# [17:40:31] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [17:40:31] Time left 1029.57 secs
#
# [17:40:37] Selector_LightGBM fitting and predicting completed
# [17:40:38] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# [17:40:53] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1906.7845220637153
# [17:40:53] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [17:40:53] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 139.44 secs
# [17:43:32] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# [17:43:32] Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# [17:44:39] Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -1784.5386953696263
# [17:44:39] Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# [17:44:39] Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
# [17:45:01] Fitting Lvl_0_Pipe_1_Mod_2_CatBoost finished. score = -1880.0040976648656
# [17:45:01] Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# [17:45:01] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ... Time budget is 300.00 secs
# [17:50:06] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# [17:50:06] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# [17:50:44] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1849.5139991238052
# [17:50:44] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [17:50:44] Time left 417.20 secs
#
# [17:50:44] Layer 1 training completed.
#
# [17:50:44] Blending: optimization starts with equal weights and score -1923.6139457293132
# [17:50:44] Blending: iteration 0: score = -1777.7947339785883, weights = [0.         0.         0.7830319  0.         0.21696813]
# [17:50:44] Blending: iteration 1: score = -1777.7947279518494, weights = [0.         0.         0.78297573 0.         0.2170243 ]
# [17:50:44] Blending: iteration 2: score = -1777.7947279518494, weights = [0.         0.         0.78297573 0.         0.2170243 ]
# [17:50:44] Blending: no score update. Terminated
#
# [17:50:44] Automl preset training completed in 625.82 seconds
#
# [17:50:44] Model description:
# Final prediction for new objects (level 0) =
# 	 0.78298 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 	 0.21702 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
#
# [17:50:44] ==================================================
# [17:50:44] Blending: optimization starts with equal weights and score -1721.3054226063496
# [17:50:44] Blending: iteration 0: score = -1715.4359032761352, weights = [0.72265923 0.27734077]
# [17:50:44] Blending: iteration 1: score = -1715.4359032761352, weights = [0.72265923 0.27734077]
# [17:50:44] Blending: no score update. Terminated
#
# CPU times: total: 1h 21min 40s
# Wall time: 23min 2s

# %%
print(automl.create_model_str_desc())
# Out:
# Final prediction for new objects =
# 	0.72266 * 1 averaged models with config = "c:\Users\avvoy\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_0_sel_type_0.yml" and different CV random_states. Their structures:
#
# 	    Model #0.
# 		================================================================================
# 		Final prediction for new objects (level 0) =
# 			 0.94055 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 			 0.05945 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
# 		================================================================================
#
#
# 	+ 0.27734 * 1 averaged models with config = "c:\Users\avvoy\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_1_sel_type_1.yml" and different CV random_states. Their structures:
#
# 	    Model #0.
# 		================================================================================
# 		Final prediction for new objects (level 0) =
# 			 0.78298 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 			 0.21702 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
# 		================================================================================

# %% [markdown]
# # 3. Prediction on holdout and model evaluation
#
# We now have the trained model called `automl` and it's time to see what MAE score it can receive on train and holdout data:

# %%
# %%time
te_pred = automl.predict(te_data)
print(f'Prediction for te_data:\n{te_pred}\nShape = {te_pred.shape}')
# Out:
# Prediction for te_data:
# array([[10354.42  ],
#        [  369.4892],
#        [ 6184.1553],
#        ...,
#        [ 4618.841 ],
#        [ 4367.351 ],
#        [ 5185.9307]], dtype=float32)
# Shape = (5631, 1)
# CPU times: total: 25 s
# Wall time: 6.32 s

# %%
mae0 = mean_absolute_error(tr_data[TARGET_NAME].values, oof_pred.data[:, 0])
print(f'TRAIN out-of-fold score: {mae0}')
experiment.log_metric('TRAIN out-of-fold score', mae0)


mae1 = mean_absolute_error(te_data[TARGET_NAME].values, te_pred.data[:, 0])
print(f'HOLDOUT score: {mae1}')
experiment.log_metric('HOLDOUT score', mae1)
# Out:
# TRAIN out-of-fold score: 1715.4359032761352
# HOLDOUT score: 1691.773560251823

# %% [markdown]
# prev values:\
# TRAIN out-of-fold score: 2434.783417413201\
# HOLDOUT score: 2574.981653039796

# %% [markdown]
# # 4. Feature importances calculation
#
# For feature importances calculation we have 2 different methods in LightAutoML:
# - Fast (`fast`) - this method uses feature importances from feature selector LGBM model inside LightAutoML. It works extremely fast and almost always (almost because of situations, when feature selection is turned off or selector was removed from the final models with all GBM models). no need to use new labelled data.
# - Accurate (`accurate`) - this method calculate *features permutation importances* for the whole LightAutoML model based on the **new labelled data**. It always works but can take a lot of time to finish (depending on the model structure, new labelled dataset size etc.).

# %%
# %%time
# # Fast feature importances calculation
# fast_fi = automl.get_feature_scores('fast')
# fast_fi.set_index('Feature')['Importance'].plot.bar(figsize = (30, 10), grid = True)

# %%
# %%time
# # Accurate feature importances calculation (Permutation importances) -  can take long time to calculate on bigger datasets
# accurate_fi = automl.get_feature_scores('accurate', te_data, silent = False)

# %%
# accurate_fi.set_index('Feature')['Importance'].plot.bar(figsize = (30, 10), grid = True)

# %% [markdown]
# # 5. Predict for test dataset
#
# We are also ready to predict for our test competition dataset and submission file creation:

# %% [markdown]
# Для более точного предсказания использую весь датасет train_data

# %%
# automl = TabularAutoML(
automl = TabularUtilizedAutoML(
    task = task, 
    timeout = TIMEOUT,
    cpu_limit = N_THREADS,
    reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE}
)

# %%
# %%time 
oof_pred = automl.fit_predict(train_data, roles = roles, verbose = 1)
# Out:
# [17:50:52] Start automl utilizator with listed constraints:
# [17:50:52] - time: 1800.00 seconds
# [17:50:52] - CPU: 4 cores
# [17:50:52] - memory: 16 GB
#
# [17:50:52] If one preset completes earlier, next preset configuration will be started
#
# [17:50:52] ==================================================
# [17:50:52] Start 0 automl preset configuration:
# [17:50:52] c:\Users\avvoy\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_0_sel_type_0.yml, random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# [17:50:52] Stdout logging level is INFO.
# [17:50:52] Task: reg
#
# [17:50:52] Start automl preset with listed constraints:
# [17:50:52] - time: 1800.00 seconds
# [17:50:52] - CPU: 4 cores
# [17:50:52] - memory: 16 GB
#
# [17:50:52] Train data shape: (28151, 15)
#
# [17:50:54] Layer 1 train process start. Time left 1797.98 secs
# [17:50:55] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# [17:51:11] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -2874.309292648178
# [17:51:11] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [17:51:11] Time left 1780.26 secs
#
# [17:51:12] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# [17:51:29] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1862.2658449297608
# [17:51:29] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [17:51:29] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 300.00 secs
# [17:56:42] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# [17:56:42] Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# [17:58:53] Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -1694.019630977618
# [17:58:53] Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# [17:58:53] Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
# [17:59:19] Fitting Lvl_0_Pipe_1_Mod_2_CatBoost finished. score = -1842.1928617799774
# [17:59:19] Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# [17:59:19] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ... Time budget is 300.00 secs
# [18:04:27] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# [18:04:27] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# [18:05:19] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1772.5004235805743
# [18:05:19] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [18:05:19] Time left 932.48 secs
#
# [18:05:19] Layer 1 training completed.
#
# [18:05:19] Blending: optimization starts with equal weights and score -1890.5588016812872
# [18:05:19] Blending: iteration 0: score = -1689.2592963237016, weights = [0.         0.         0.8126888  0.         0.18731117]
# [18:05:19] Blending: iteration 1: score = -1689.2592963237016, weights = [0.         0.         0.8126889  0.         0.18731117]
# [18:05:19] Blending: iteration 2: score = -1689.2592963237016, weights = [0.         0.         0.8126889  0.         0.18731117]
# [18:05:19] Blending: no score update. Terminated
#
# [18:05:19] Automl preset training completed in 867.69 seconds
#
# [18:05:19] Model description:
# Final prediction for new objects (level 0) =
# 	 0.81269 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 	 0.18731 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
#
# [18:05:19] ==================================================
# [18:05:19] Start 1 automl preset configuration:
# [18:05:19] c:\Users\avvoy\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_1_sel_type_1.yml, random state: {'reader_params': {'random_state': 43}, 'general_params': {'return_all_predictions': False}}
# [18:05:19] Stdout logging level is INFO.
# [18:05:19] Task: reg
#
# [18:05:19] Start automl preset with listed constraints:
# [18:05:19] - time: 932.29 seconds
# [18:05:19] - CPU: 4 cores
# [18:05:19] - memory: 16 GB
#
# [18:05:19] Train data shape: (28151, 15)
#
# [18:05:22] Layer 1 train process start. Time left 930.14 secs
# [18:05:23] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# [18:05:37] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -2713.4936302184788
# [18:05:37] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [18:05:37] Time left 914.59 secs
#
# [18:05:40] Selector_LightGBM fitting and predicting completed
# [18:05:41] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# [18:06:00] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1893.7635502055214
# [18:06:00] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [18:06:00] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 143.67 secs
# [18:08:30] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# [18:08:30] Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# [18:09:20] Time limit exceeded after calculating fold 2
#
# [18:09:20] Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -1694.9151009821665
# [18:09:20] Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# [18:09:20] Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
# [18:09:46] Fitting Lvl_0_Pipe_1_Mod_2_CatBoost finished. score = -1893.4450955780521
# [18:09:46] Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# [18:09:46] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ... Time budget is 300.00 secs
# [18:14:46] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# [18:14:46] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# [18:15:35] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1825.5083900438922
# [18:15:35] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [18:15:35] Time left 316.89 secs
#
# [18:15:35] Time limit exceeded in one of the tasks. AutoML will blend level 1 models.
#
# [18:15:35] Layer 1 training completed.
#
# [18:15:35] Blending: optimization starts with equal weights and score -1930.2390493325393
# [18:15:35] Blending: iteration 0: score = -1694.9151009821665, weights = [0. 0. 1. 0. 0.]
# [18:15:35] Blending: iteration 1: score = -1694.9151009821665, weights = [0. 0. 1. 0. 0.]
# [18:15:35] Blending: no score update. Terminated
#
# [18:15:35] Automl preset training completed in 615.52 seconds
#
# [18:15:35] Model description:
# Final prediction for new objects (level 0) =
# 	 1.00000 * (3 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM)
#
# [18:15:35] ==================================================
# [18:15:35] Blending: optimization starts with equal weights and score -1675.1926861598324
# [18:15:35] Blending: iteration 0: score = -1675.0197434718898, weights = [0.553111 0.446889]
# [18:15:35] Blending: iteration 1: score = -1675.0197434718898, weights = [0.553111 0.446889]
# [18:15:35] Blending: no score update. Terminated
#
# CPU times: total: 1h 26min 49s
# Wall time: 24min 43s

# %%
mae2 = mean_absolute_error(train_data[TARGET_NAME].values, oof_pred.data[:, 0])
print(f'FULL TRAIN score: {mae2}')
experiment.log_metric('FULL TRAIN score', mae2)
# Out:
# FULL TRAIN score: 1675.0197434718898

# %%
test_pred = automl.predict(test_data)
print(f'Prediction for te_data:\n{test_pred}\nShape = {test_pred.shape}')
# Out:
# Prediction for te_data:
# array([[ 3347.4717],
#        [ 5791.756 ],
#        [ 4534.093 ],
#        ...,
#        [15899.508 ],
#        [ 5249.6865],
#        [ 6084.5386]], dtype=float32)
# Shape = (10697, 1)

# %%
submission[TARGET_NAME] = test_pred.data[:, 0]
submission
# Out:
#        row_ID  final_price
# 0       35000      3347.47
# 1       35001      5791.76
# 2       35002      4534.09
# 3       35003       355.25
# 4       35004      5144.22
# ...       ...          ...
# 10692   45692      1433.01
# 10693   45693      1572.55
# 10694   45694     15899.51
# 10695   45695      5249.69
# 10696   45696      6084.54
#
# [10697 rows x 2 columns]

# %% [markdown]
# ### Проверка и замена нулевой записи

# %%
# Должно быть ноль
submission[submission['row_ID'] == 37254]
# Out:
#       row_ID  final_price
# 2254   37254      2339.47

# %%
# Если не ноль, то принудительно меняю
ind = submission[submission['row_ID'] == 37254].index
submission.at[ind, 'final_price'] = 0

# %%
submission.to_csv(submission_file_name, index = False)

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/chepell/predict-car-price/24ebdb1131664694b99fb91a2d9c4c2c
# COMET INFO:   Metrics:
# COMET INFO:     FULL TRAIN score        : 1675.0197434718898
# COMET INFO:     HOLDOUT score           : 1691.773560251823
# COMET INFO:     TRAIN out-of-fold score : 1715.4359032761352
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (406.66 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO:     text-sample              : 1
# COMET INFO: ---------------------------
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: torch, lightgbm, sklearn. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 2 file(s), remaining 105.79 KB/252.66 KB
