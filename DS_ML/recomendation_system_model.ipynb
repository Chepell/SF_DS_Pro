# %% [markdown]
# # <center> Разбор кейса ML-инженера

# %% [markdown]
# ## Обучим и протестируем модель

# %%
# !pip install lightfm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lightfm
#   Using cached lightfm-1.17.tar.gz (316 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from lightfm) (1.24.3)
# Requirement already satisfied: scipy>=0.17.0 in c:\program files\python310\lib\site-packages (from lightfm) (1.9.1)
# Requirement already satisfied: requests in c:\program files\python310\lib\site-packages (from lightfm) (2.27.1)
# Requirement already satisfied: scikit-learn in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from lightfm) (1.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\program files\python310\lib\site-packages (from requests->lightfm) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python310\lib\site-packages (from requests->lightfm) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\program files\python310\lib\site-packages (from requests->lightfm) (2.0.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python310\lib\site-packages (from requests->lightfm) (3.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from scikit-learn->lightfm) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\program files\python310\lib\site-packages (from scikit-learn->lightfm) (3.1.0)
# Building wheels for collected packages: lightfm
#   Building wheel for lightfm (setup.py): started
#   Building wheel for lightfm (setup.py): finished with status 'done'
#   Created wheel for lightfm: filename=lightfm-1.17-cp310-cp310-win_amd64.whl size=419887 sha256=a008407a692381ad50f3115f88a0f60ab6abf9229a321a3f7def5c81cf7eac9e
#   Stored in directory: c:\users\avvoy\appdata\local\pip\cache\wheels\4f\9b\7e\0b256f2168511d8fa4dae4fae0200fdbd729eb424a912ad636
# Successfully built lightfm
# Installing collected packages: lightfm
# Successfully installed lightfm-1.17

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sparse

from lightfm import LightFM
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k
import pickle
# Out:
# C:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
ratings = pd.read_csv("data/ratings.csv")
books = pd.read_csv("data/books.csv")
tags = pd.read_csv("data/tags.csv")
book_tags = pd.read_csv("data/book_tags.csv")

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn
# 0        1            2767052       2767052  2792775          272  439023483  \
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year
# 0  9.780439e+12              Suzanne Collins                     2008.0  \
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count
# 0                          The Hunger Games  ...       4780653  \
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2
# 0            4942365                   155254      66715     127936  \
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5
# 0     560092    1481305    2706317  \
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url
# 0  https://images.gr-assets.com/books/1447303603m...  \
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
book_tags
# Out:
#         goodreads_book_id  tag_id   count
# 0                       1   30574  167697
# 1                       1   11305   37174
# 2                       1   11557   34173
# 3                       1    8717   12986
# 4                       1   33114   12716
# ...                   ...     ...     ...
# 999907           33288638   21303       7
# 999908           33288638   17271       7
# 999909           33288638    1126       7
# 999910           33288638   11478       7
# 999911           33288638   27939       7
#
# [999912 rows x 3 columns]

# %%
tags
# Out:
#        tag_id    tag_name
# 0           0           -
# 1           1        --1-
# 2           2       --10-
# 3           3       --12-
# 4           4      --122-
# ...       ...         ...
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ
#
# [34252 rows x 2 columns]

# %%
mapper = dict(zip(books["goodreads_book_id"], books["book_id"]))

# %%
tags = pd.read_csv("data/tags_cleaned.csv")
book_tags = book_tags[book_tags.tag_id.isin(tags.tag_id)]
book_tags["id"] = book_tags.goodreads_book_id.map(mapper)
book_tags
# Out:
# C:\Users\avvoy\AppData\Local\Temp\ipykernel_10380\3634255909.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_tags['id'] = book_tags.goodreads_book_id.map(mapper)
#         goodreads_book_id  tag_id  count    id
# 1                       1   11305  37174    27
# 4                       1   33114  12716    27
# 5                       1   11743   9954    27
# 6                       1   14017   7169    27
# 10                      1   27199   3857    27
# ...                   ...     ...    ...   ...
# 999877           33288638    9886     10  8892
# 999879           33288638    3358     10  8892
# 999880           33288638    1679     10  8892
# 999889           33288638    1659      9  8892
# 999890           33288638   29316      9  8892
#
# [300738 rows x 4 columns]

# %%
book_tags.head()

# %%
ratings_coo = sparse.coo_matrix((ratings.rating, (ratings.user_id, ratings.book_id)))
feature_ratings = sparse.coo_matrix(
    ([1] * len(book_tags), (book_tags.id, book_tags.tag_id))
)

# %% [markdown]
# Объявим вспомогательные константы для обучения модели:

# %%
# число потоков нашего процессора. Ставим 1, так как lightfm на macos ставится без OpenMP
NUM_THREADS = 1

# число параметров вектора
NUM_COMPONENTS = 60

# число эпох обучения
NUM_EPOCHS = 10

# зерно датчика случайных чисел
RANDOM_STATE = 42

# %% [markdown]
# На этапе создания модели мы используем библиотеку LightFM, чтобы сделать матричное разложение (ALS) наших рейтингов книг и получить два набора векторов.

# %%
# Разбиваем наш датасет на обучающую и тестовую выборки
train, test = random_train_test_split(
    ratings_coo, test_percentage=0.2, random_state=RANDOM_STATE
)

# Создаём модель
model = LightFM(
    learning_rate=0.05,  # темп (скорость) обучения
    loss="warp",  # loss-функция
    no_components=NUM_COMPONENTS,  # размерность вектора признаков
    random_state=RANDON_STATE,  # генератор случайных чисел
)

# Обучаем модель
model = model.fit(
    train,  # обучающая выборка
    epochs=NUM_EPOCHS,  # количество эпох обучения
    num_threads=NUM_THREADS,  # количество потоков процессора
    item_features=feature_ratings,  # признаки товаров (рейтинги книг)
)

# %% [markdown]
# Протестируем модель

# %%
# Тестируем нашу модель
precision_score = precision_at_k(
    model,  # модель
    test,  # тестовая выборка
    num_threads=NUM_THREADS,  # количество потоков процессора
    k=10,  # количество предложений
    item_features=feature_ratings,  # признаки товаров
).mean()  # усредняем результаты

recall_score = recall_at_k(
    model,  # модель
    test,  # тестовая выборка
    num_threads=NUM_THREADS,  # количество потоков процессора
    k=10,  # количество предложений
    item_features=feature_ratings,  # признаки товаров
).mean()  # усредняем результаты

print(recall_score, precision_score)

# %% [markdown]
# Сохраним модель

# %%
with open("model.pkl", "wb") as file:
    pickle.dump(model, file, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Добавим эмбеддинги к модели и посмотрим, что получилось

# %%
with open("model.pkl", "rb") as file:
    model = pickle.load(file)

# %%
# Достаём эбмеддинги
item_biases, item_embeddings = model.get_item_representations(features=feature_ratings)

print(item_biases.shape, item_embeddings.shape)

# %%
# !pip install nmslib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nmslib
#   Using cached nmslib-2.1.1.tar.gz (188 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pybind11<2.6.2 (from nmslib)
#   Using cached pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
# Requirement already satisfied: psutil in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from nmslib) (5.9.1)
# Requirement already satisfied: numpy>=1.10.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from nmslib) (1.24.3)
# Building wheels for collected packages: nmslib
#   Building wheel for nmslib (setup.py): started
#   Building wheel for nmslib (setup.py): finished with status 'error'
#   Running setup.py clean for nmslib
# Failed to build nmslib
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [1101 lines of output]
#       Dependence list: ['pybind11<2.6.2', 'psutil', "numpy>=1.10.0,<1.17 ; python_version=='2.7'", "numpy>=1.10.0 ; python_version>='3.5'"]
#       C:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\setuptools\dist.py:745: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               By 2023-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       C:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\setuptools\__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       C:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\setuptools\dist.py:745: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               By 2023-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       running bdist_wheel
#       running build
#       running build_ext
#       Extra compilation arguments: ['/EHsc', '/openmp', '/O2', '/DVERSION_INFO=\\"2.1.1\\"']
#       building 'nmslib' extension
#       creating build
#       creating build\temp.win-amd64-cpython-310
#       creating build\temp.win-amd64-cpython-310\Release
#       creating build\temp.win-amd64-cpython-310\Release\similarity_search
#       creating build\temp.win-amd64-cpython-310\Release\similarity_search\src
#       creating build\temp.win-amd64-cpython-310\Release\similarity_search\src\method
#       creating build\temp.win-amd64-cpython-310\Release\similarity_search\src\space
#       creating build\temp.win-amd64-cpython-310\Release\tensorflow
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_bregman.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_bregman.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_bregman.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_diverg.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_diverg.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_diverg.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\distcomp_diverg.cc(61): warning C4244: '+=': conversion from 'double' to 'T', possible loss of data
#               with
#               [
#                   T=float
#               ]
#       .\similarity_search\src\distcomp_diverg.cc(66): note: see reference to function template instantiation 'float similarity::alphaBetaDivergenceSlowProxy<float>(const float *,const float *,const int,float,float)' being compiled
#       .\similarity_search\src\distcomp_diverg.cc(73): warning C4244: '+=': conversion from 'double' to 'T', possible loss of data
#               with
#               [
#                   T=float
#               ]
#       .\similarity_search\src\distcomp_diverg.cc(79): note: see reference to function template instantiation 'float similarity::alphaBetaDivergenceFastProxy<float>(const float *,const float *,const int,float,float)' being compiled
#       .\similarity_search\src\distcomp_diverg.cc(84): warning C4305: 'initializing': truncation from 'double' to 'T'
#               with
#               [
#                   T=float
#               ]
#       .\similarity_search\src\distcomp_diverg.cc(95): note: see reference to function template instantiation 'float similarity::renyiDivergenceSlow<float>(const float *,const float *,const int,float)' being compiled
#       .\similarity_search\src\distcomp_diverg.cc(101): warning C4305: 'initializing': truncation from 'double' to 'T'
#               with
#               [
#                   T=float
#               ]
#       .\similarity_search\src\distcomp_diverg.cc(111): note: see reference to function template instantiation 'float similarity::renyiDivergenceFast<float>(const float *,const float *,const int,float)' being compiled
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_edist.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_edist.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_edist.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\distcomp_edist.cc(39): warning C4267: 'return': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\src\distcomp_edist.cc(76): note: see reference to function template instantiation 'int similarity::levenshtein<char>(const char *,size_t,const char *,size_t)' being compiled
#       .\similarity_search\src\distcomp_edist.cc(49): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\src\distcomp_edist.cc(57): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_js.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_js.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_js.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\distcomp_js.cc(226): warning C4244: 'return': conversion from 'double' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_l2sqr_sift.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_l2sqr_sift.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_l2sqr_sift.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\distcomp_l2sqr_sift.cc(89): warning C4267: 'initializing': conversion from 'size_t' to 'uint_fast32_t', possible loss of data
#       .\similarity_search\src\distcomp_l2sqr_sift.cc(103) : WARNING: l2SqrSIFTPrecompAVX: AVX2 is not available
#       .\similarity_search\src\distcomp_l2sqr_sift.cc(105) : WARNING: l2SqrSIFTPrecompAVX: SSE4 is not available
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_lp.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_lp.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_lp.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\distcomp_lp.cc(249): warning C4244: 'return': conversion from 'double' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_overlap.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_overlap.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_overlap.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_rankcorr.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_rankcorr.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_rankcorr.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\distcomp_rankcorr.cc(40) : WARNING: SpearmanFootruleSIMD: SSE4.2 is not available, defaulting to pure C++ implementation!
#       .\similarity_search\src\distcomp_rankcorr.cc(112) : WARNING: SpearmanRhoSIMD: SSE4.2 is not available, defaulting to pure C++ implementation!
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_scalar.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_scalar.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_scalar.cc
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\distcomp_sparse_scalar_fast.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\distcomp_sparse_scalar_fast.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       distcomp_sparse_scalar_fast.cc
#       .\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\distcomp_sparse_scalar_fast.cc(231) : WARNING: No SSE 4.2, defaulting to scalar implementation!
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\experimentconf.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\experimentconf.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       experimentconf.cc
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\src\experimentconf.cc(218): warning C4267: 'initializing': conversion from 'size_t' to 'unsigned int', possible loss of data
#       .\similarity_search\src\experimentconf.cc(201): note: while compiling class template member function 'void similarity::ExperimentConfig<float>::Write(std::ostream &,std::ostream &)'
#       .\similarity_search\src\experimentconf.cc(428): note: see reference to class template instantiation 'similarity::ExperimentConfig<float>' being compiled
#       .\similarity_search\src\experimentconf.cc(232): warning C4018: '>=': signed/unsigned mismatch
#       .\similarity_search\src\experimentconf.cc(241): warning C4267: '=': conversion from 'size_t' to 'unsigned int', possible loss of data
#       .\similarity_search\src\experimentconf.cc(388): warning C4267: '=': conversion from 'size_t' to '_Ty', possible loss of data
#               with
#               [
#                   _Ty=similarity::IdType
#               ]
#       .\similarity_search\src\experimentconf.cc(341): note: while compiling class template member function 'void similarity::ExperimentConfig<float>::ReadDataset(void)'
#       .\similarity_search\src\experimentconf.cc(139): warning C4244: 'argument': conversion from 'float' to 'const T', possible loss of data
#               with
#               [
#                   T=int
#               ]
#       .\similarity_search\src\experimentconf.cc(50): note: while compiling class template member function 'void similarity::ExperimentConfig<int>::Read(std::istream &,std::istream &,size_t &)'
#       .\similarity_search\src\experimentconf.cc(139): warning C4244: 'argument': conversion from 'float' to 'const T', possible loss of data
#               with
#               [
#                   T=int
#               ]
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\global.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\global.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       global.cc
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\init.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\init.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       init.cc
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\permutation_utils.h(175): warning C4334: '<<': result of 32-bit shift implicitly converted to 64 bits (was 64-bit shift intended?)
#       .\similarity_search\include\method/pivot_neighb_common.h(57): warning C4267: 'argument': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\method/small_world_rand.h(90): warning C4267: 'initializing': conversion from 'size_t' to 'similarity::IdType', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\include\space/space_sparse_bin_common.h(149): warning C4267: '+=': conversion from 'size_t' to 'unsigned int', possible loss of data
#       .\similarity_search\include\space/space_sparse_bin_common.h(183): warning C4267: '+=': conversion from 'size_t' to 'unsigned int', possible loss of data
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\space\space_bit_vector.h(143): warning C4267: 'argument': conversion from 'size_t' to '_Ty', possible loss of data
#               with
#               [
#                   _Ty=std::seed_seq::result_type
#               ]
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\space\space_bit_vector.h(142): note: while compiling class template member function 'similarity::Object *similarity::SpaceBitVector<dist_t,dist_uint_t>::CreateObjFromVect(similarity::IdType,similarity::LabelType,std::vector<std::seed_seq::result_type,std::allocator<std::seed_seq::result_type>> &) const'
#               with
#               [
#                   dist_t=float,
#                   dist_uint_t=uint32_t
#               ]
#       .\similarity_search\include\space/space_bit_jaccard.h(35): note: see reference to class template instantiation 'similarity::SpaceBitVector<dist_t,dist_uint_t>' being compiled
#               with
#               [
#                   dist_t=float,
#                   dist_uint_t=uint32_t
#               ]
#       .\similarity_search\include\factory/space/space_bit_jaccard.h(28): note: see reference to class template instantiation 'similarity::SpaceBitJaccard<dist_t,dist_uint_t>' being compiled
#               with
#               [
#                   dist_t=float,
#                   dist_uint_t=uint32_t
#               ]
#       .\similarity_search\include\factory/init_spaces.h(49): note: see reference to function template instantiation 'similarity::Space<float> *similarity::CreateBitJaccard<float,uint32_t>(const similarity::AnyParams &)' being compiled
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\space\space_bit_vector.h(60): warning C4267: '=': conversion from 'size_t' to 'unsigned int', possible loss of data
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\space\space_bit_vector.h(46): note: while compiling class template member function 'std::unique_ptr<similarity::Object,std::default_delete<similarity::Object>> similarity::SpaceBitVector<dist_t,dist_uint_t>::CreateObjFromStr(similarity::IdType,similarity::LabelType,const std::string &,similarity::DataFileInputState *) const'
#               with
#               [
#                   dist_t=float,
#                   dist_uint_t=uint32_t
#               ]
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\space\space_bit_vector.h(201): warning C4267: 'argument': conversion from 'size_t' to '_Ty', possible loss of data
#               with
#               [
#                   _Ty=std::seed_seq::result_type
#               ]
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\space\space_bit_vector.h(156): note: while compiling class template member function 'void similarity::SpaceBitVector<dist_t,dist_uint_t>::ReadBitMaskVect(std::string,similarity::LabelType &,std::vector<std::seed_seq::result_type,std::allocator<std::seed_seq::result_type>> &) const'
#               with
#               [
#                   dist_t=float,
#                   dist_uint_t=uint32_t
#               ]
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\space\space_bit_vector.h(57): note: see the first reference to 'similarity::SpaceBitVector<dist_t,dist_uint_t>::ReadBitMaskVect' in 'similarity::SpaceBitVector<dist_t,dist_uint_t>::CreateObjFromStr'
#               with
#               [
#                   dist_t=float,
#                   dist_uint_t=uint32_t
#               ]
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\knnquery.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\knnquery.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       knnquery.cc
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\src\knnquery.cc(63): warning C4267: 'return': conversion from 'size_t' to 'unsigned int', possible loss of data
#       .\similarity_search\src\knnquery.cc(62): note: while compiling class template member function 'unsigned int similarity::KNNQuery<float>::ResultSize(void) const'
#       .\similarity_search\src\knnquery.cc(134): note: see reference to class template instantiation 'similarity::KNNQuery<float>' being compiled
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\logging.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\logging.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       logging.cc
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\memory.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\memory.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       memory.cc
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\method\dummy.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\method\dummy.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       dummy.cc
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\method\hnsw.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\method\hnsw.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       hnsw.cc
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
# ...
#       space_sparse_vector.cc
#       .\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\space\space_sparse_vector_inter.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\space\space_sparse_vector_inter.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       space_sparse_vector_inter.cc
#       .\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\space\space_sparse_vector_inter.cc(210): warning C4244: 'initializing': conversion from 'double' to 'float', possible loss of data
#       .\similarity_search\src\space\space_sparse_vector_inter.cc(89): note: while compiling class template member function 'similarity::OverlapInfo similarity::SpaceSparseVectorInter<float>::ComputeOverlapInfo(const std::vector<similarity::SparseVectElem<float>,std::allocator<similarity::SparseVectElem<float>>> &,const std::vector<similarity::SparseVectElem<float>,std::allocator<similarity::SparseVectElem<float>>> &)'
#       .\similarity_search\src\space\space_sparse_vector_inter.cc(250): note: see reference to class template instantiation 'similarity::SpaceSparseVectorInter<float>' being compiled
#       .\similarity_search\src\space\space_sparse_vector_inter.cc(214): warning C4244: 'initializing': conversion from 'double' to 'float', possible loss of data
#       .\similarity_search\include\space/space_sparse_vector_inter.h(203): warning C4267: 'argument': conversion from 'size_t' to 'uint32_t', possible loss of data
#       .\similarity_search\src\space\space_sparse_vector_inter.cc(37): note: see reference to function template instantiation 'void similarity::UnpackSparseElements<float>(const char *,size_t,std::vector<similarity::SparseVectElem<float>,std::allocator<similarity::SparseVectElem<float>>> &)' being compiled
#       .\similarity_search\src\space\space_sparse_vector_inter.cc(32): note: while compiling class template member function 'void similarity::SpaceSparseVectorInter<float>::CreateDenseVectFromObj(const similarity::Object *,dist_t *,size_t) const'
#               with
#               [
#                   dist_t=float
#               ]
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\space\space_string.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\space\space_string.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       space_string.cc
#       .\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\space\space_vector.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\space\space_vector.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       space_vector.cc
#       .\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       .\similarity_search\src\space\space_vector.cc(66): warning C4267: '=': conversion from 'size_t' to 'unsigned int', possible loss of data
#       .\similarity_search\src\space\space_vector.cc(54): note: while compiling class template member function 'std::unique_ptr<similarity::Object,std::default_delete<similarity::Object>> similarity::VectorSpace<similarity::PivotIdType>::CreateObjFromStr(similarity::IdType,similarity::LabelType,const std::string &,similarity::DataFileInputState *) const'
#       .\similarity_search\src\space\space_vector.cc(146): note: see reference to class template instantiation 'similarity::VectorSpace<similarity::PivotIdType>' being compiled
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\space\space_word_embed.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\space\space_word_embed.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       space_word_embed.cc
#       .\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tp.\similarity_search\src\utils.cc /Fobuild\temp.win-amd64-cpython-310\Release\.\similarity_search\src\utils.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       utils.cc
#       .\similarity_search\src\utils.cc(42): warning C4267: 'initializing': conversion from 'size_t' to 'int', possible loss of data
#       .\similarity_search\src\utils.cc(59): warning C4267: 'initializing': conversion from 'size_t' to 'int', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -I.\similarity_search\include -Itensorflow -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -Ic:\users\avvoy\appdata\local\temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\.eggs\pybind11-2.6.1-py3.10.egg\pybind11\include -IC:\Users\avvoy\AppData\Roaming\Python\Python310\site-packages\numpy\core\include "-Ic:\Program Files\Python310\include" "-Ic:\Program Files\Python310\Include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpnmslib.cc /Fobuild\temp.win-amd64-cpython-310\Release\nmslib.obj /EHsc /openmp /O2 /DVERSION_INFO=\\\"2.1.1\\\"
#       nmslib.cc
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\object.h(127): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#       C:\Users\avvoy\AppData\Local\Temp\pip-install-wa3a69ip\nmslib_ecaff00023034a04b7ac076eada35c47\similarity_search\include\distcomp.h(260): warning C4244: 'initializing': conversion from 'size_t' to 'float', possible loss of data
#       nmslib.cc(454): error C2017: illegal escape sequence
#       nmslib.cc(454): error C2001: newline in constant
#       nmslib.cc(459): error C2143: syntax error: missing ')' before 'pybind11::enum_<similarity::DistType>'
#       nmslib.cc(459): error C2143: syntax error: missing ';' before 'pybind11::enum_<similarity::DistType>'
#       nmslib.cc(730): warning C4267: '=': conversion from 'size_t' to 'T', possible loss of data
#               with
#               [
#                   T=int
#               ]
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.37.32822\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for nmslib
# ERROR: Could not build wheels for nmslib, which is required to install pyproject.toml-based projects

# %%
import nmslib

# %%
# Инициализируем наш граф для поиска
nms_idx = nmslib.init(method="hnsw", space="cosinesimil")

# Начинаем добавлять наши книги в граф
nms_idx.addDataPointBatch(item_embeddings)
nms_idx.createIndex(print_progress=True)

# %%
# Вспомогательная функция для поиска по графу
def nearest_books_nms(book_id, index, n=10):
    nn = index.knnQuery(item_embeddings[book_id], k=n)
    return nn

# %% [markdown]
# Найдем id книги 1984

# %%
# Отфильтруем только те, где в названии встречается подстрока "1984"
books[books["title"].apply(lambda x: x.lower().find("1984")) >= 0]

# %% [markdown]
# Теперь найдем все похожие книги и посмотрим на них

# %%
# Вызываем функцию для поиска ближайших соседей
print(nearest_books_nms(846, nms_idx))

# %%
# Выделяем идентификаторы рекомендованных книг
nbm = nearest_books_nms(846, nms_idx)[0]
nbm

# %%
# Посмотрим на авторов и названия рекомендованных книг
books[books.book_id.isin(nbm)][["authors", "title"]]

# %% [markdown]
# Сохраним эмбеддинги

# %%
with open("item_embeddings.pkl", "wb") as file:
    pickle.dump(item_embeddings, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/50/28/fdfe9711d553cfaf217cafc9b8ba21479c663b6504cc96652465b153e04b/streamlit-1.26.0-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.26.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/f2/b4/02a0221bd1da91f6e6acdf0525528db24b4b326a670a9048da474dfe0667/altair-5.1.1-py3-none-any.whl.metadata
#   Downloading altair-5.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (8.1.6)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\program files\python310\lib\site-packages (from streamlit) (4.12.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (21.3)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (2.0.0)
# Requirement already satisfied: pillow<10,>=7.1.0 in c:\program files\python310\lib\site-packages (from streamlit) (9.0.1)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (4.22.3)
# Requirement already satisfied: pyarrow>=6.0 in c:\program files\python310\lib\site-packages (from streamlit) (7.0.0)
# Collecting pympler<2,>=0.9 (from streamlit)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ------------------------------------ 164.8/164.8 kB 761.4 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in c:\program files\python310\lib\site-packages (from streamlit) (2.27.1)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from streamlit) (13.3.5)
# Collecting tenacity<9,>=8.1.0 (from streamlit)
#   Obtaining dependency information for tenacity<9,>=8.1.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\program files\python310\lib\site-packages (from streamlit) (0.10.2)
# Collecting typing-extensions<5,>=4.1.0 (from streamlit)
#   Obtaining dependency information for typing-extensions<5,>=4.1.0 from https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.7.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\program files\python310\lib\site-packages (from streamlit) (4.1)
# Collecting validators<1,>=0.2 (from streamlit)
#   Obtaining dependency information for validators<1,>=0.2 from https://files.pythonhosted.org/packages/3a/0c/785d317eea99c3739821718f118c70537639aa43f96bfa1d83a71f68eaf6/validators-0.22.0-py3-none-any.whl.metadata
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/0f/c6/bb9e2276b6fed126aa21e292493b45a3df4cfba7cbfcf2ab8809a6b0e718/GitPython-3.1.35-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.35-py3-none-any.whl.metadata (10 kB)
# Collecting pydeck<1,>=0.8 (from streamlit)
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\program files\python310\lib\site-packages (from streamlit) (6.1)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
#      -------------------------------------- 82.0/82.0 kB 241.8 kB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\program files\python310\lib\site-packages (from altair<6,>=4.0->streamlit) (4.4.0)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\program files\python310\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      -------------------------------------- 62.7/62.7 kB 160.0 kB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\program files\python310\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\program files\python310\lib\site-packages (from packaging<24,>=16.8->streamlit) (3.0.7)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python310\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\program files\python310\lib\site-packages (from requests<3,>=2.18->streamlit) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python310\lib\site-packages (from requests<3,>=2.18->streamlit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\program files\python310\lib\site-packages (from requests<3,>=2.18->streamlit) (2.0.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python310\lib\site-packages (from requests<3,>=2.18->streamlit) (3.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\program files\python310\lib\site-packages (from tzlocal<5,>=1.1->streamlit) (0.1.0.post0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\program files\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\program files\python310\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\avvoy\appdata\roaming\python\python310\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Downloading streamlit-1.26.0-py2.py3-none-any.whl (8.1 MB)
#    ---------------------------------------- 8.1/8.1 MB 990.7 kB/s eta 0:00:00
# Downloading altair-5.1.1-py3-none-any.whl (520 kB)
#    ---------------------------------------- 520.6/520.6 kB 1.1 MB/s eta 0:00:00
# Downloading GitPython-3.1.35-py3-none-any.whl (188 kB)
#    -------------------------------------- 188.8/188.8 kB 544.5 kB/s eta 0:00:00
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Installing collected packages: watchdog, validators, typing-extensions, toolz, tenacity, smmap, pympler, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.1.1 gitdb-4.0.10 gitpython-3.1.35 pydeck-0.8.0 pympler-1.0.1 smmap-5.0.0 streamlit-1.26.0 tenacity-8.2.3 toolz-0.12.0 typing-extensions-4.7.1 validators-0.22.0 watchdog-3.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.3 which is incompatible.
