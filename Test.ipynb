# %%
print('Hello!')
# Out:
# Hello!

# %%
x = 10

# %%
y_pred = 0.4

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\avvoy\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords = nltk.corpus.stopwords.words("russian")

# %%
len(stopwords)
# Out:
# 151

# %%
import pandas as pd

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/List_of_European_Union_cities_proper_by_population_density')[5]
data.drop(['Rank', 'Area (sq. miles)', 'Density (/sq. mile)'], axis=1, inplace=True)

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.1-cp39-cp39-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-4.9.1

# %%
data
# Out:
#                          City    Population Area (km2) Density (/km2)  \
# 0            Levallois-Perret         66082       2.41          27420
# 1                   Emperador           692       0.03          23067
# 2   L'Hospitalet de Llobregat        264923       12.4          21364
# 3                       Paris       2203817      105.4          20909
# 4                     Mislata         43278       2.10          20608
# 5                  Benetússer         14668       0.76          19300
# 6                      Athens        745514      38.96          19135
# 7                Thessaloniki        325182      19.31          16840
# 8                   Barcelona       1621537      101.9          15991
# 9                  Korydallos         63445       4.32          14686
# 10                    Senglea          2784        0.2          13920
# 11                     Nikaia         89380       6.65          13441
# 12                    Portici         53801       4.52          11903
# 13                   Odivelas         59604       5.02          11873
# 14                 Casavatore         18644       1.62          11508
# 15      San Giorgio a Cremano         47244       4.11          11495
# 16                       Lyon        500715      47.87          10460
# 17                      Cádiz        116979      12.10           9700
# 18                    Piraeus        448997      50.42           8906
# 19                     Bilbao        353187      40.65           8688
# 20                  Bucharest       1926334        228           8449
# 21                     Naples        959574     117.27           8183
# 22              Agualva-Cacém         81020      10.42           7775
# 23                      Milan       1366037     181.76           7519
# 24                   Brussels  1,212,352[1]   162.4[2]           7465
# 25                      Porto        287591      41.42           6900
# 26                      Turin        883281     130.17           6786
# 27                   A Coruña        246056      37.83           6510
# 28                     Lisbon        505526     100.05           6446
# 29                  The Hague        527748      98.12           6445
# 30                   Valencia        780834     134.65           5799
# 31                     Madrid       3141991      604.3           5390
# 32                  Amsterdam        851573     165.76           5135
# 33                   Bordeaux        250776      49.36           5081
# 34                    Seville        703021        140           5022
# 35                  Stockholm        942370        188           5012
# 36                Montpellier        275318      56.88           4840
# 37                     Dublin        553165     114.99           4811
# 38                       Nice        343895      71.92           4782
# 39                  Munich[3]       1471508     310.70           4736
# 40                     Dublin        554554     117.80           4708
# 41                     Vienna       1889083     414.65           4556
# 42                 Copenhagen        794128     179.80           4417
# 43                    Palermo        668630     160.59           4164
# 44               Ottobrunn[3]         21542       5.23           4119
# 45                      Malmö        316588    77.0605           4108
# 46                  Berlin[3]       3644826     891.12           4090
# 47                   Toulouse        479638     118.30           4054
# 48              Saint-Nicolas     24,251[4]       6.89       3,518[5]
# 49                  Warsaw[6]       1777972     517.24           3421
# 50                       Rome       4355725       1285           3389
# 51                    Mortsel     25,824[4]       7.70       3,355[5]
# 52                    Plovdiv        346893     101.98       3,349[7]
# 53                   Budapest  1,752,286[8]     525.14           3337
# 54              Gröbenzell[3]         19967       6.36           3139
# 55               Stuttgart[3]        634830     207.33           3062
# 56                   Herne[3]        156374      51.42           3041
# 57       Frankfurt am Main[3]        753056     248.31           3033
#
#         Country
# 0        France
# 1         Spain
# 2         Spain
# 3        France
# 4         Spain
# 5         Spain
# 6        Greece
# 7        Greece
# 8         Spain
# 9        Greece
# 10        Malta
# 11       Greece
# 12        Italy
# 13     Portugal
# 14        Italy
# 15        Italy
# 16       France
# 17        Spain
# 18       Greece
# 19        Spain
# 20      Romania
# 21        Italy
# 22     Portugal
# 23        Italy
# 24      Belgium
# 25     Portugal
# 26        Italy
# 27        Spain
# 28     Portugal
# 29  Netherlands
# 30        Spain
# 31        Spain
# 32  Netherlands
# 33       France
# 34        Spain
# 35       Sweden
# 36       France
# 37      Ireland
# 38       France
# 39      Germany
# 40      Ireland
# 41      Austria
# 42      Denmark
# 43        Italy
# 44      Germany
# 45       Sweden
# 46      Germany
# 47       France
# 48      Belgium
# 49       Poland
# 50        Italy
# 51      Belgium
# 52     Bulgaria
# 53      Hungary
# 54      Germany
# 55      Germany
# 56      Germany
# 57      Germany
