# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean = 0  # mean of the distribution
std_dev = 1  # standard deviation of the distribution
size = 1000  # number of samples

random_numbers = np.random.normal(mean, std_dev, size)

# %%
plt.figure(figsize=(15, 10))
plt.hist(random_numbers, 50)
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(random_numbers)
plt.show()

# %%
np.mean(random_numbers)
# Out:
# 0.021069523505298043

# %%
np.std(random_numbers)
# Out:
# 0.988020101764518

# %%
cum_nums = np.cumsum(random_numbers)

# %%
plt.figure(figsize=(15, 10))
plt.plot(cum_nums)
plt.show()

# %% [markdown]
# Случайные числа из нормального распределения при кумулятивном суммировании образуют тренды )))
